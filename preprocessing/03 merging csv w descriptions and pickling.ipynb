# %%
import pandas as pd

# %%
to_datetime = lambda d: datetime.strptime(d, '%m/%d/%Y %H:%M:%S %p')

# %%
df = pd.read_csv('../data/311__Service_Requests.csv')
df.head(2)
# Out:
#    CASE_ENQUIRY_ID                 OPEN_DT               TARGET_DT  \
# 0     101000958209  11/01/2013 09:27:19 AM  11/15/2013 09:27:19 AM
# 1     101001243239  01/06/2015 03:26:49 PM  01/21/2015 03:26:00 PM
#
#                 CLOSED_DT OnTime_Status CASE_STATUS  \
# 0  11/27/2013 10:15:45 AM       OVERDUE      Closed
# 1  01/12/2015 10:49:02 PM        ONTIME      Closed
#
#                                       CLOSURE_REASON        CASE_TITLE  \
# 0                          Case Closed Case Resolved       Sign Repair
# 1  Case Closed Case Resolved replaced LED. jouber...  outage///printed
#
#                              SUBJECT           REASON         ...          \
# 0  Transportation - Traffic Division  Signs & Signals         ...
# 1            Public Works Department    Street Lights         ...
#
#   precinct land_usage                    LOCATION_STREET_NAME  \
# 0     0308        NaN  INTERSECTION Devonshire St & Summer St
# ...

# %%
df.ix[:0, 5:]
# Out:
#   CASE_STATUS                                     CLOSURE_REASON  \
# 0      Closed                          Case Closed Case Resolved
# 1      Closed  Case Closed Case Resolved replaced LED. jouber...
#
#          CASE_TITLE                            SUBJECT           REASON  \
# 0       Sign Repair  Transportation - Traffic Division  Signs & Signals
# 1  outage///printed            Public Works Department    Street Lights
#
#                    TYPE                             QUEUE Department  \
# 0           Sign Repair  BTDT_Sign Shop_Sign Installation       BTDT
# 1  Street Light Outages         PWDx_Street Light Outages       PWDx
#
#   SubmittedPhoto ClosedPhoto         ...         precinct  land_usage  \
# 0            NaN         NaN         ...             0308         NaN
# 1            NaN         NaN         ...             1404          RL
#
#                      LOCATION_STREET_NAME  LOCATION_ZIPCODE Property_Type  \
# ...
