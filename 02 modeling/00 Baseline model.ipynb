# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd
from datetime import datetime

# %% [raw]
# Should I hold out the same 20% of data for my test set?

# %% [markdown]
# ## Preprocessing

# %%
df = pd.read_hdf('../data/data_w_descs_and_census.h5')

# %% [raw]
# TODO: randomize the rows using a seed, chop off the last 20%, make baseline model on that.

# %%
def dummify(df,column):
    # https://github.com/zipfian/DSI_Lectures/blob/master/linear-regression/darren_reger/LR%20Notebook.ipynb
    print '{} is your baseline'.format(sorted(df[column].unique())[-1])
    dummy = pd.get_dummies(df[column]).rename(columns=lambda x: column+'_'+str(x)).iloc[:,0:len(df[column].unique())-1]
    df = df.drop(column,axis=1) #Why not inplace? because if we do inplace, it will affect the df directly
    return pd.concat([df,dummy],axis=1)

# %%
# df = dummify(df, 'neighborhood')
# df = dummify(df, 'TYPE')
# Out:
# West Roxbury is your baseline
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-a5168215a548> in <module>()
#       1 df = dummify(df, 'neighborhood')
# ----> 2 df = dummify(df, 'type')
#
# <ipython-input-78-0e9d8954c1ae> in dummify(df, column)
#       1 def dummify(df,column):
#       2     # https://github.com/zipfian/DSI_Lectures/blob/master/linear-regression/darren_reger/LR%20Notebook.ipynb
# ----> 3     print '{} is your baseline'.format(sorted(df[column].unique())[-1])
#       4     dummy = pd.get_dummies(df[column]).rename(columns=lambda x: column+'_'+str(x)).iloc[:,0:len(df[column].unique())-1]
#       5     df = df.drop(column,axis=1) #Why not inplace? because if we do inplace, it will affect the df directly
#
# /home/aok1425/miniconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# /home/aok1425/miniconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# /home/aok1425/miniconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /home/aok1425/miniconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3539
#    3540             if not isnull(item):
# -> 3541                 loc = self.items.get_loc(item)
#    3542             else:
#    3543                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/aok1425/miniconda2/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4443)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4289)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13733)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13687)()
#
# KeyError: 'type'

# %%
df.shape
# Out:
# (127923, 75)

# %% [markdown]
# ## Fitting basic linear model

# %%
est = smf.ols('resolution_hours ~ LATITUDE + LONGITUDE + C(neighborhood) + C(TYPE)', df).fit()
est.summary()
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 8.11 µs
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       resolution_hours   R-squared:                       0.216
# Model:                            OLS   Adj. R-squared:                  0.215
# Method:                 Least Squares   F-statistic:                     475.1
# Date:                Thu, 12 Jan 2017   Prob (F-statistic):               0.00
# Time:                        23:45:50   Log-Likelihood:            -1.0474e+06
# No. Observations:              127923   AIC:                         2.095e+06
# Df Residuals:                  127848   BIC:                         2.096e+06
# Df Model:                          74
# Covariance Type:            nonrobust
# ===================================================================================================================================
#                                                                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                       -4192.8887   1.85e+04     -0.226      0.821     -4.05e+04  3.21e+04
# C(neighborhood)[T.Allston / Brighton]                              86.6514     63.345      1.368      0.171       -37.503   210.806
# C(neighborhood)[T.Back Bay]                                        56.8558     64.306      0.884      0.377       -69.183   182.894
# C(neighborhood)[T.Beacon Hill]                                      1.5459     64.690      0.024      0.981      -125.245   128.337
# C(neighborhood)[T.Boston]                                           4.1052     65.539      0.063      0.950      -124.351   132.561
# C(neighborhood)[T.Brighton]                                        88.1077     79.727      1.105      0.269       -68.156   244.372
# C(neighborhood)[T.Charlestown]                                     51.7798     65.266      0.793      0.428       -76.141   179.700
# C(neighborhood)[T.Chestnut Hill]                                  494.2797    873.102      0.566      0.571     -1216.985  2205.545
# C(neighborhood)[T.Dorchester]                                     110.2070     65.906      1.672      0.094       -18.968   239.382
# C(neighborhood)[T.Downtown / Financial District]                   47.5303     64.541      0.736      0.461       -78.969   174.030
# C(neighborhood)[T.East Boston]                                     18.8732     65.741      0.287      0.774      -109.979   147.725
# C(neighborhood)[T.Fenway / Kenmore / Audubon Circle / Longwood]    80.3518     64.782      1.240      0.215       -46.619   207.323
# C(neighborhood)[T.Greater Mattapan]                               115.7107     66.466      1.741      0.082       -14.561   245.983
# C(neighborhood)[T.Hyde Park]                                      134.0669     66.539      2.015      0.044         3.652   264.482
# C(neighborhood)[T.Jamaica Plain]                                  131.4374     64.475      2.039      0.041         5.068   257.807
# C(neighborhood)[T.Mattapan]                                       169.8625    112.360      1.512      0.131       -50.362   390.087
# C(neighborhood)[T.Mission Hill]                                    96.1573     65.609      1.466      0.143       -32.436   224.750
# C(neighborhood)[T.Roslindale]                                     125.8833     65.725      1.915      0.055        -2.937   254.703
# C(neighborhood)[T.Roxbury]                                         69.9880     64.596      1.083      0.279       -56.618   196.594
# C(neighborhood)[T.South Boston]                                  -100.5983     75.142     -1.339      0.181      -247.875    46.679
# C(neighborhood)[T.South Boston / South Boston Waterfront]          -7.7398     65.640     -0.118      0.906      -136.393   120.914
# C(neighborhood)[T.South End]                                       25.8835     64.509      0.401      0.688      -100.552   152.319
# C(neighborhood)[T.West Roxbury]                                   180.2070     65.680      2.744      0.006        51.476   308.938
# C(TYPE)[T.Abandoned Vehicles]                                     281.7598     40.202      7.009      0.000       202.965   360.555
# C(TYPE)[T.Big Buildings Recycling (INTERNAL)]                    -953.5259    111.501     -8.552      0.000     -1172.066  -734.986
# C(TYPE)[T.CE Collection]                                          613.3148     34.421     17.818      0.000       545.851   680.779
# C(TYPE)[T.Catchbasin]                                            -134.3906     53.814     -2.497      0.013      -239.866   -28.915
# C(TYPE)[T.Empty Litter Basket]                                    543.0578     36.337     14.945      0.000       471.837   614.279
# C(TYPE)[T.Equipment Repair]                                        19.9400     40.953      0.487      0.626       -60.328   100.208
# C(TYPE)[T.General Lighting Request]                               324.3030     49.872      6.503      0.000       226.555   422.051
# C(TYPE)[T.Graffiti Removal]                                        10.9683     35.182      0.312      0.755       -57.988    79.924
# C(TYPE)[T.Ground Maintenance]                                     351.9928     40.815      8.624      0.000       271.996   431.989
# C(TYPE)[T.Improper Storage of Trash (Barrels)]                    610.7433     35.515     17.197      0.000       541.134   680.352
# C(TYPE)[T.Knockdown Replacement]                                 -779.7214    150.948     -5.165      0.000     -1075.577  -483.866
# C(TYPE)[T.Major System Failure]                                   577.8410    309.593      1.866      0.062       -28.957  1184.638
# C(TYPE)[T.Misc. Snow Complaint]                                   556.6654    124.168      4.483      0.000       313.298   800.033
# C(TYPE)[T.Missed Trash/Recycling/Yard Waste/Bulk Item]            599.4982     59.155     10.134      0.000       483.555   715.441
# C(TYPE)[T.Missing Sign]                                           315.7185     48.066      6.568      0.000       221.509   409.928
# C(TYPE)[T.Needle Pickup]                                          293.3138     41.676      7.038      0.000       211.629   374.998
# C(TYPE)[T.New Sign  Crosswalk or Pavement Marking]              -3567.1372     66.101    -53.965      0.000     -3696.695 -3437.579
# C(TYPE)[T.New Tree Requests]                                    -4818.9017     55.741    -86.452      0.000     -4928.153 -4709.650
# C(TYPE)[T.News Boxes]                                             496.5407     45.194     10.987      0.000       407.961   585.120
# C(TYPE)[T.One Boston Day]                                         501.3536    277.334      1.808      0.071       -42.216  1044.923
# C(TYPE)[T.PWD Graffiti]                                           419.9765     37.806     11.109      0.000       345.877   494.076
# C(TYPE)[T.Park Improvement Requests]                            -2159.3879    120.132    -17.975      0.000     -2394.844 -1923.931
# C(TYPE)[T.Parking Enforcement]                                    598.0913     34.008     17.587      0.000       531.437   664.746
# C(TYPE)[T.Parks Lighting/Electrical Issues]                      -485.7161     67.536     -7.192      0.000      -618.086  -353.346
# C(TYPE)[T.Pest Infestation - Residential]                         216.9913     76.893      2.822      0.005        66.283   367.699
# C(TYPE)[T.Pick up Dead Animal]                                    581.6178     40.187     14.473      0.000       502.851   660.384
# C(TYPE)[T.Pickup/Clear Conduit]                                    41.7808    616.504      0.068      0.946     -1166.557  1250.118
# C(TYPE)[T.Planting]                                             -2952.9866    356.977     -8.272      0.000     -3652.655 -2253.318
# C(TYPE)[T.Poor Conditions of Property]                            589.4523     38.077     15.481      0.000       514.823   664.082
# C(TYPE)[T.Recycling Cart Return]                                  592.3292     41.813     14.166      0.000       510.376   674.282
# C(TYPE)[T.Rental Unit Delivery Conditions]                        609.8268    616.495      0.989      0.323      -598.493  1818.146
# C(TYPE)[T.Request for Pothole Repair]                             512.6664     34.411     14.898      0.000       445.221   580.112
# C(TYPE)[T.Request for Recycling Cart]                            -173.3305     41.842     -4.143      0.000      -255.340   -91.321
# C(TYPE)[T.Request for Snow Plowing]                               194.6998     36.505      5.334      0.000       123.151   266.249
# C(TYPE)[T.Requests for Street Cleaning]                           573.3042     33.867     16.928      0.000       506.926   639.682
# C(TYPE)[T.Rodent Activity]                                        295.3674     58.824      5.021      0.000       180.074   410.661
# C(TYPE)[T.Sidewalk Repair (Make Safe)]                             38.6730     34.793      1.112      0.266       -29.521   106.867
# C(TYPE)[T.Sign Repair]                                            328.7755     35.530      9.253      0.000       259.137   398.414
# C(TYPE)[T.Snow Removal]                                           539.2748    131.319      4.107      0.000       281.892   796.658
# C(TYPE)[T.Space Savers]                                           589.4115    871.203      0.677      0.499     -1118.131  2296.953
# C(TYPE)[T.Street Light Knock Downs]                               467.7854    235.065      1.990      0.047         7.063   928.508
# C(TYPE)[T.Street Light Outages]                                  -143.7061     35.640     -4.032      0.000      -213.560   -73.852
# C(TYPE)[T.StreetLight Pole WO]                                    394.9848    227.300      1.738      0.082       -50.519   840.488
# C(TYPE)[T.Student Move-in Issues]                                 471.4901     94.924      4.967      0.000       285.441   657.540
# C(TYPE)[T.Traffic Signal Inspection]                              479.7531     43.457     11.040      0.000       394.578   564.928
# C(TYPE)[T.Traffic Signal Repair]                                  532.8708    390.819      1.363      0.173      -233.128  1298.869
# C(TYPE)[T.Tree Maintenance Requests]                             -784.0983     36.641    -21.400      0.000      -855.913  -712.283
# C(TYPE)[T.Unsatisfactory Living Conditions]                       531.0834    227.267      2.337      0.019        85.643   976.524
# C(TYPE)[T.Unshoveled Sidewalk]                                    586.3643     40.160     14.601      0.000       507.651   665.077
# C(TYPE)[T.Utility Casting Repair]                                -217.0721     59.489     -3.649      0.000      -333.669  -100.475
# LATITUDE                                                          509.8902    185.098      2.755      0.006       147.102   872.678
# LONGITUDE                                                         254.1864    183.762      1.383      0.167      -105.983   614.356
# ==============================================================================
# Omnibus:                   179094.097   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         64063974.375
# Skew:                          -8.231   Prob(JB):                         0.00
# Kurtosis:                     111.389   Cond. No.                     6.30e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.3e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [raw]
# 14s for 127k rows.
