# %% [raw]
# Only include the one feature I think means the most at first.

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd
from datetime import datetime

from sklearn.cross_validation import train_test_split
from sklearn.model_selection import ShuffleSplit
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import PolynomialFeatures
# Out:
# /home/ubuntu/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [raw]
# Should I hold out the same 20% of data for my test set?

# %% [markdown]
# ## Preprocessing

# %% [raw]
# TODO: randomize the rows using a seed, chop off the last 20%, make baseline model on that.

# %%
def dummify(df, column):
    # https://github.com/zipfian/DSI_Lectures/blob/master/linear-regression/darren_reger/LR%20Notebook.ipynb
    if type(df) == pd.Series:
        df = pd.DataFrame(df)
    
    print '{} is your baseline'.format(sorted(df[column].unique())[-1])
    dummy = pd.get_dummies(df[column]).rename(columns=lambda x: column+'_'+str(x)).iloc[:,0:len(df[column].unique())-1]
    df = df.drop(column,axis=1) #Why not inplace? because if we do inplace, it will affect the df directly
    return pd.concat([df,dummy],axis=1)

# %%
df = pd.read_hdf('../data/data_till_june_2016_w_descs_and_census.h5')

# %%
df = df.dropna(subset=['CLOSED_DT'])

# %%
df.shape
# Out:
# (718936, 155)

# %% [markdown]
# ## Setting aside 20% for the test set

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df.drop('COMPLETION_TIME', axis=1), 
    df.COMPLETION_TIME, 
    test_size=0.2, 
    random_state=300
)

# %% [markdown]
# ## Setting aside another 20% for the CV set

# %%
X_CV_train, X_CV_test, y_CV_train, y_CV_test = train_test_split(
    X_train, 
    y_train, 
    test_size=0.2, 
    random_state=300
)

# %% [markdown]
# ## Fitting basic linear model

# %%
def get_rmse(est):
    return (est.ssr / (est.nobs - 2))**0.5

# %%
est = smf.ols(
    'COMPLETION_TIME ~ C(TYPE)', 
    pd.concat([X_CV_train, y_CV_train], axis=1)).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        COMPLETION_TIME   R-squared:                       0.254
# Model:                            OLS   Adj. R-squared:                  0.254
# Method:                 Least Squares   F-statistic:                     500.2
# Date:                Mon, 30 Jan 2017   Prob (F-statistic):               0.00
# Time:                        04:19:29   Log-Likelihood:            -2.6449e+06
# No. Observations:              295228   AIC:                         5.290e+06
# Df Residuals:                  295026   BIC:                         5.292e+06
# Df Model:                         201
# Covariance Type:            nonrobust
# ================================================================================================================================
#                                                                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                     6010.8016    665.455      9.033      0.000      4706.528  7315.075
# C(TYPE)[T.Abandoned Bicycle]                                 -5415.7685    670.440     -8.078      0.000     -6729.812 -4101.725
# C(TYPE)[T.Abandoned Building]                                -4382.0527    676.233     -6.480      0.000     -5707.450 -3056.656
# C(TYPE)[T.Abandoned Vehicles]                                -5730.9712    666.069     -8.604      0.000     -7036.448 -4425.494
# C(TYPE)[T.Alert Boston]                                      -5904.8983    782.003     -7.551      0.000     -7437.601 -4372.195
# C(TYPE)[T.Animal Found]                                      -5538.8280    717.725     -7.717      0.000     -6945.549 -4132.107
# C(TYPE)[T.Animal Generic Request]                            -5915.5075    674.448     -8.771      0.000     -7237.407 -4593.608
# C(TYPE)[T.Animal Lost]                                       -5514.7986    721.003     -7.649      0.000     -6927.943 -4101.654
# C(TYPE)[T.Animal Noise Disturbances]                         -5592.5116    799.778     -6.993      0.000     -7160.053 -4024.970
# C(TYPE)[T.Automotive Noise Disturbance]                      -5647.8965   1016.500     -5.556      0.000     -7640.207 -3655.586
# C(TYPE)[T.BWSC General Request]                              -5532.8287    673.284     -8.218      0.000     -6852.447 -4213.210
# C(TYPE)[T.BWSC Pothole]                                      -5553.5400    737.597     -7.529      0.000     -6999.209 -4107.871
# C(TYPE)[T.Base Repair (Internal)]                              859.9167   1016.500      0.846      0.398     -1132.394  2852.228
# C(TYPE)[T.Bed Bugs]                                          -4897.3836    671.631     -7.292      0.000     -6213.762 -3581.005
# C(TYPE)[T.Bicycle Issues]                                    -3855.1026    741.744     -5.197      0.000     -5308.899 -2401.306
# C(TYPE)[T.Big Buildings Online Request]                      -5198.7328    728.970     -7.132      0.000     -6627.493 -3769.973
# C(TYPE)[T.Big Buildings Recycling (INTERNAL)]                -4461.2573    681.889     -6.543      0.000     -5797.740 -3124.775
# C(TYPE)[T.Big Buildings Resident Complaint]                   1.565e-11   1.26e-11      1.245      0.213     -8.99e-12  4.03e-11
# C(TYPE)[T.Billing Complaint]                                 -3876.3269    824.019     -4.704      0.000     -5491.381 -2261.273
# C(TYPE)[T.Boston Public Health Commission (BPHC)]            -5908.3811   1996.366     -2.960      0.003     -9821.202 -1995.560
# C(TYPE)[T.Breathe Easy]                                      -4042.2249    671.718     -6.018      0.000     -5358.774 -2725.675
# C(TYPE)[T.Bridge Maintenance]                                -5558.4230    748.945     -7.422      0.000     -7026.334 -4090.511
# C(TYPE)[T.Building Inspection Request]                       -4423.0949    666.125     -6.640      0.000     -5728.682 -3117.508
# C(TYPE)[T.CE Collection]                                     -6002.5906    666.391     -9.008      0.000     -7308.699 -4696.482
# C(TYPE)[T.Call Log]                                          -6006.5003    668.833     -8.981      0.000     -7317.395 -4695.606
# C(TYPE)[T.Capital Improvement Long Term]                      2.087e-10   4.43e-11      4.709      0.000      1.22e-10  2.96e-10
# C(TYPE)[T.Carbon Monoxide]                                   -5463.6019    737.597     -7.407      0.000     -6909.271 -4017.933
# C(TYPE)[T.Catchbasin]                                        -5336.0458    669.247     -7.973      0.000     -6647.751 -4024.340
# C(TYPE)[T.Cemetery Maintenance Request]                      -4766.7533    727.487     -6.552      0.000     -6192.607 -3340.900
# C(TYPE)[T.Checkin]                                           -6010.7887    892.802     -6.733      0.000     -7760.655 -4260.922
# C(TYPE)[T.Chronic Dampness/Mold]                             -4725.0852    673.171     -7.019      0.000     -6044.481 -3405.689
# C(TYPE)[T.City/State Snow Issues]                            -5839.7705    685.177     -8.523      0.000     -7182.698 -4496.843
# C(TYPE)[T.Construction Debris]                               -5986.6424    732.160     -8.177      0.000     -7421.655 -4551.629
# C(TYPE)[T.Contractor Complaints]                             -5392.4985    667.796     -8.075      0.000     -6701.361 -4083.636
# C(TYPE)[T.Contractors Complaint]                             -4479.4927    668.935     -6.696      0.000     -5790.586 -3168.399
# C(TYPE)[T.Corporate or Community Group Service Day Clean Up] -4104.3869    714.814     -5.742      0.000     -5505.401 -2703.372
# C(TYPE)[T.Cross Metering - Sub-Metering]                     -4939.1152    675.615     -7.311      0.000     -6263.302 -3614.928
# C(TYPE)[T.Downed Wire]                                       -6007.8950    874.579     -6.869      0.000     -7722.046 -4293.744
# C(TYPE)[T.Dumpster & Loading Noise Disturbances]             -5900.5169   1274.250     -4.631      0.000     -8398.011 -3403.023
# C(TYPE)[T.Egress]                                            -3470.1355    684.609     -5.069      0.000     -4811.950 -2128.321
# C(TYPE)[T.Electrical]                                        -4086.4600    667.666     -6.121      0.000     -5395.067 -2777.853
# C(TYPE)[T.Empty Litter Basket]                               -5936.9659    666.463     -8.908      0.000     -7243.214 -4630.718
# C(TYPE)[T.Equipment Repair]                                  -5180.5602    667.003     -7.767      0.000     -6487.867 -3873.253
# C(TYPE)[T.Exceeding Terms of Permit]                         -2802.7980    676.547     -4.143      0.000     -4128.811 -1476.785
# C(TYPE)[T.Fire Department Request]                           -5872.2412    768.401     -7.642      0.000     -7378.287 -4366.196
# C(TYPE)[T.Fire Hydrant]                                      -5592.2184    673.852     -8.299      0.000     -6912.950 -4271.486
# C(TYPE)[T.Fire in Food Establishment]                        -5935.4843    728.970     -8.142      0.000     -7364.244 -4506.724
# C(TYPE)[T.Flooding Residential/Commercial]                    1.847e-11   1.33e-11      1.389      0.165     -7.59e-12  4.45e-11
# C(TYPE)[T.Follow-Up]                                         -5842.4305   1488.003     -3.926      0.000     -8758.875 -2925.986
# C(TYPE)[T.Food Alert - Confirmed]                            -5911.0372    690.110     -8.565      0.000     -7263.634 -4558.441
# C(TYPE)[T.Food Alert - Unconfirmed]                          -5892.3542    681.688     -8.644      0.000     -7228.444 -4556.264
# C(TYPE)[T.General Comments For An Employee]                  -5727.4782    668.529     -8.567      0.000     -7037.776 -4417.180
# C(TYPE)[T.General Comments For a Program or Policy]          -5719.2168    666.467     -8.581      0.000     -7025.473 -4412.961
# C(TYPE)[T.General Lighting Request]                          -4767.4802    666.528     -7.153      0.000     -6073.857 -3461.104
# C(TYPE)[T.General Traffic Engineering Request]               -4958.8172    689.884     -7.188      0.000     -6310.970 -3606.665
# C(TYPE)[T.Graffiti Removal]                                  -5509.2314    665.830     -8.274      0.000     -6814.239 -4204.224
# C(TYPE)[T.Ground Maintenance]                                -5716.9884    667.231     -8.568      0.000     -7024.742 -4409.234
# C(TYPE)[T.HP Sign Application New]                            5.589e-11   3.14e-11      1.779      0.075     -5.68e-12  1.17e-10
# C(TYPE)[T.HP Sign Application Renewal]                       -4546.5650   1996.366     -2.277      0.023     -8459.386  -633.744
# C(TYPE)[T.Heat - Excessive  Insufficient]                    -5034.0984    667.821     -7.538      0.000     -6343.009 -3725.187
# C(TYPE)[T.Heat/Fuel Assistance]                              -5832.1790    941.096     -6.197      0.000     -7676.700 -3987.658
# C(TYPE)[T.Hero Square Sign Request]                          -4.305e-12   6.51e-12     -0.661      0.509     -1.71e-11  8.46e-12
# C(TYPE)[T.Highway Maintenance]                               -5155.9307    666.524     -7.736      0.000     -6462.299 -3849.563
# C(TYPE)[T.Housing Discrimination Intake Form]                -5569.2727    685.032     -8.130      0.000     -6911.915 -4226.630
# C(TYPE)[T.Idea Collection]                                   -5944.8505   1152.602     -5.158      0.000     -8203.919 -3685.782
# C(TYPE)[T.Illegal Auto Body Shop]                            -4503.8960    681.991     -6.604      0.000     -5840.579 -3167.213
# C(TYPE)[T.Illegal Dumping]                                   -5997.7255    675.977     -8.873      0.000     -7322.621 -4672.830
# C(TYPE)[T.Illegal Occupancy]                                 -3492.5449    669.812     -5.214      0.000     -4805.357 -2179.733
# C(TYPE)[T.Illegal Posting of Signs]                          -5952.6196    768.401     -7.747      0.000     -7458.665 -4446.574
# C(TYPE)[T.Illegal Rooming House]                             -3486.3330    673.284     -5.178      0.000     -4805.952 -2166.714
# C(TYPE)[T.Illegal Use]                                       -2889.2188    722.188     -4.001      0.000     -4304.688 -1473.750
# C(TYPE)[T.Illegal Vending]                                   -6004.8194    892.802     -6.726      0.000     -7754.686 -4254.953
# C(TYPE)[T.Improper Storage of Trash (Barrels)]               -5998.7753    668.160     -8.978      0.000     -7308.351 -4689.200
# C(TYPE)[T.Install New Lighting]                              -3764.2758    688.409     -5.468      0.000     -5113.537 -2415.014
# C(TYPE)[T.Item Price Missing]                                -5979.0579    793.275     -7.537      0.000     -7533.855 -4424.261
# C(TYPE)[T.Knockdown Replacement]                             -3225.3948    671.167     -4.806      0.000     -4540.864 -1909.926
# C(TYPE)[T.Lead]                                              -4428.3849    715.747     -6.187      0.000     -5831.230 -3025.540
# C(TYPE)[T.Litter Basket Maintenance]                         -5872.2203    678.254     -8.658      0.000     -7201.578 -4542.862
# C(TYPE)[T.Loud Parties/Music/People]                         -5623.5463    793.275     -7.089      0.000     -7178.344 -4068.749
# C(TYPE)[T.MBTA Request]                                      -5846.2912    874.579     -6.685      0.000     -7560.443 -4132.140
# C(TYPE)[T.Maintenance - Homeowner]                           -4337.0002    673.852     -6.436      0.000     -5657.732 -3016.268
# C(TYPE)[T.Maintenance Complaint - Residential]               -4906.5812    673.284     -7.288      0.000     -6226.200 -3586.963
# C(TYPE)[T.Major System Failure]                              -5584.4529    667.632     -8.365      0.000     -6892.992 -4275.914
# C(TYPE)[T.Mechanical]                                        -4656.9482    693.194     -6.718      0.000     -6015.590 -3298.307
# C(TYPE)[T.Metrolist Survey]                                  -1125.1875    669.464     -1.681      0.093     -2437.318   186.943
# C(TYPE)[T.Mice Infestation - Residential]                    -5009.7822    671.464     -7.461      0.000     -6325.833 -3693.732
# C(TYPE)[T.Misc. Snow Complaint]                              -5653.2234    669.488     -8.444      0.000     -6965.402 -4341.045
# C(TYPE)[T.Miscellaneous Event]                               -6010.2294   1996.366     -3.011      0.003     -9923.050 -2097.409
# C(TYPE)[T.Missed Trash/Recycling/Yard Waste/Bulk Item]       -5988.5666    665.607     -8.997      0.000     -7293.137 -4683.996
# C(TYPE)[T.Missing Sign]                                      -5726.3520    667.359     -8.581      0.000     -7034.357 -4418.347
# C(TYPE)[T.Mosquitoes (West Nile)]                            -4617.0450    760.977     -6.067      0.000     -6108.539 -3125.551
# C(TYPE)[T.Municipal Parking Lot Complaints]                  -5097.3283    799.778     -6.373      0.000     -6664.870 -3529.787
# C(TYPE)[T.Needle Pickup]                                     -5424.7125    670.478     -8.091      0.000     -6738.830 -4110.595
# C(TYPE)[T.New Sign  Crosswalk or Pavement Marking]           -4730.3986    666.686     -7.095      0.000     -6037.085 -3423.712
# C(TYPE)[T.New Tree Requests]                                  -964.3882    666.398     -1.447      0.148     -2270.510   341.733
# C(TYPE)[T.New Tree Warrantee Inspection]                      -694.6874   1152.602     -0.603      0.547     -2953.756  1564.381
# C(TYPE)[T.News Boxes]                                        -5872.7680    670.142     -8.763      0.000     -7186.227 -4559.309
# C(TYPE)[T.No Price on Gas/Wrong Price]                       -5982.7287    760.977     -7.862      0.000     -7474.223 -4491.235
# C(TYPE)[T.No Utilities - Food Establishment - Electricity]   -5952.3304    974.127     -6.110      0.000     -7861.591 -4043.069
# C(TYPE)[T.No Utilities - Food Establishment - Flood]         -5959.1025    941.096     -6.332      0.000     -7803.624 -4114.581
# C(TYPE)[T.No Utilities - Food Establishment - Sewer]         -5977.3266   1016.500     -5.880      0.000     -7969.637 -3985.016
# C(TYPE)[T.No Utilities - Food Establishment - Water]         -4587.5042    974.127     -4.709      0.000     -6496.765 -2678.243
# C(TYPE)[T.No Utilities Residential - Electricity]            -5045.3834    693.194     -7.278      0.000     -6404.025 -3686.742
# C(TYPE)[T.No Utilities Residential - Gas]                    -4596.5986    726.071     -6.331      0.000     -6019.678 -3173.519
# C(TYPE)[T.No Utilities Residential - Water]                  -5097.8786    680.843     -7.488      0.000     -6432.313 -3763.444
# C(TYPE)[T.No-Tow Complaint Confirmation]                     -5977.0884    676.189     -8.839      0.000     -7302.400 -4651.777
# C(TYPE)[T.Notification]                                      -5921.4696    666.844     -8.880      0.000     -7228.465 -4614.474
# C(TYPE)[T.OCR Front Desk Interactions]                       -6010.8441    667.226     -9.009      0.000     -7318.589 -4703.099
# C(TYPE)[T.OCR Metrolist]                                     -5807.6587    806.983     -7.197      0.000     -7389.323 -4225.995
# C(TYPE)[T.Occupying W/Out A Valid CO/CI]                     -2052.8908    732.160     -2.804      0.005     -3487.904  -617.878
# C(TYPE)[T.One Boston Day]                                    -5872.2290   1016.500     -5.777      0.000     -7864.540 -3879.918
# C(TYPE)[T.Overcrowding]                                      -4844.2785    718.774     -6.740      0.000     -6253.055 -3435.502
# C(TYPE)[T.Overflowing or Un-kept Dumpster]                   -4828.0861    669.877     -7.207      0.000     -6141.026 -3515.146
# C(TYPE)[T.PWD Graffiti]                                      -5782.5383    666.886     -8.671      0.000     -7089.617 -4475.460
# C(TYPE)[T.Park Improvement Requests]                          -550.4254    678.254     -0.812      0.417     -1879.783   778.933
# C(TYPE)[T.Park Maintenance Requests]                           706.9236    676.831      1.044      0.296      -619.647  2033.494
# C(TYPE)[T.Parking Enforcement]                               -5980.9834    665.757     -8.984      0.000     -7285.848 -4676.119
# C(TYPE)[T.Parking Meter Repairs]                             -5616.5122    676.783     -8.299      0.000     -6942.988 -4290.037
# C(TYPE)[T.Parking on Front/Back Yards (Illegal Parking)]     -5980.3451    705.218     -8.480      0.000     -7362.553 -4598.137
# C(TYPE)[T.Parks General Request]                             -4569.6674    673.425     -6.786      0.000     -5889.562 -3249.773
# C(TYPE)[T.Parks Lighting/Electrical Issues]                  -4684.7880    671.293     -6.979      0.000     -6000.503 -3369.073
# C(TYPE)[T.Pavement Marking Inspection]                       -5867.8182    700.503     -8.377      0.000     -7240.784 -4494.852
# C(TYPE)[T.Pavement Marking Maintenance]                      -3798.5990    670.366     -5.666      0.000     -5112.498 -2484.700
# C(TYPE)[T.Pest Infestation - Residential]                    -4995.3393    674.240     -7.409      0.000     -6316.832 -3673.847
# C(TYPE)[T.Phone Bank Service Inquiry]                        -5701.1872    764.550     -7.457      0.000     -7199.683 -4202.691
# C(TYPE)[T.Pick up Dead Animal]                               -5999.5996    666.070     -9.007      0.000     -7305.078 -4694.121
# C(TYPE)[T.Pickup/Clear Conduit]                              -6010.6894   1996.366     -3.011      0.003     -9923.510 -2097.869
# C(TYPE)[T.Pigeon Infestation]                                -2782.3585    709.867     -3.920      0.000     -4173.677 -1391.040
# C(TYPE)[T.Planting]                                          -4658.1888    739.612     -6.298      0.000     -6107.808 -3208.570
# C(TYPE)[T.Plumbing]                                          -4626.6216    672.093     -6.884      0.000     -5943.906 -3309.338
# C(TYPE)[T.Poor Conditions of Property]                       -5987.6125    669.163     -8.948      0.000     -7299.152 -4676.073
# C(TYPE)[T.Poor Ventilation]                                  -5823.8348    859.099     -6.779      0.000     -7507.645 -4140.025
# C(TYPE)[T.Pothole Repair (Internal)]                         -6010.7971    665.641     -9.030      0.000     -7315.435 -4706.159
# C(TYPE)[T.Private Parking Lot Complaints]                    -4096.0373    815.013     -5.026      0.000     -5693.440 -2498.635
# C(TYPE)[T.Product Short Measure]                             -5975.0754    914.581     -6.533      0.000     -7767.628 -4182.523
# C(TYPE)[T.Protection of Adjoining Property]                  -3650.1742    673.774     -5.418      0.000     -4970.752 -2329.597
# C(TYPE)[T.Public Events Noise Disturbances]                  -5983.7027   1488.003     -4.021      0.000     -8900.147 -3067.258
# C(TYPE)[T.Public Works General Request]                      -5398.9567    668.040     -8.082      0.000     -6708.295 -4089.618
# C(TYPE)[T.Rat Bite]                                          -5056.9798    764.550     -6.614      0.000     -6555.476 -3558.484
# C(TYPE)[T.Recycling Cart Inquiry]                            -4533.0677    671.885     -6.747      0.000     -5849.943 -3216.192
# C(TYPE)[T.Recycling Cart Return]                             -5846.4034    666.967     -8.766      0.000     -7153.640 -4539.167
# C(TYPE)[T.Rental Unit Delivery Conditions]                   -4386.3762    701.945     -6.249      0.000     -5762.169 -3010.583
# C(TYPE)[T.Request for Litter Basket Installation]            -5753.6569    676.831     -8.501      0.000     -7080.227 -4427.086
# C(TYPE)[T.Request for Pothole Repair]                        -5889.5356    665.653     -8.848      0.000     -7194.197 -4584.874
# C(TYPE)[T.Request for Recycling Cart]                        -5511.8414    665.836     -8.278      0.000     -6816.861 -4206.822
# C(TYPE)[T.Request for Snow Plowing]                          -5759.9362    665.575     -8.654      0.000     -7064.444 -4455.429
# C(TYPE)[T.Request for Snow Plowing (Emergency Responder)]    -5850.5116    669.569     -8.738      0.000     -7162.849 -4538.174
# C(TYPE)[T.Requests for Street Cleaning]                      -5982.7597    665.585     -8.989      0.000     -7287.288 -4678.232
# C(TYPE)[T.Requests for Traffic Signal Studies or Reviews]    -5096.0116    669.422     -7.613      0.000     -6408.060 -3783.963
# C(TYPE)[T.Roadway Flooding]                                  -5963.9794    757.654     -7.872      0.000     -7448.960 -4478.999
# C(TYPE)[T.Roadway Repair]                                     -336.1773    672.849     -0.500      0.617     -1654.943   982.589
# C(TYPE)[T.Rodent Activity]                                   -4908.7626    666.095     -7.369      0.000     -6214.290 -3603.235
# C(TYPE)[T.Rooftop & Mechanical Disturbances]                 -5722.2166    974.127     -5.874      0.000     -7631.478 -3812.956
# C(TYPE)[T.Scale Not Visible]                                 -6010.7790   1274.250     -4.717      0.000     -8508.273 -3513.285
# C(TYPE)[T.Scanning Overcharge]                               -5929.8434    824.019     -7.196      0.000     -7544.897 -4314.790
# C(TYPE)[T.Schedule a Bulk Item Pickup]                       -5896.8769    665.539     -8.860      0.000     -7201.315 -4592.438
# C(TYPE)[T.Schedule a Bulk Item Pickup SS]                    -5887.0132    665.808     -8.842      0.000     -7191.979 -4582.048
# C(TYPE)[T.Senior Shoveling]                                  -5610.8562   1488.003     -3.771      0.000     -8527.301 -2694.412
# C(TYPE)[T.Sewage/Septic Back-Up]                             -4467.7036    700.971     -6.374      0.000     -5841.587 -3093.820
# C(TYPE)[T.Short Measure - Gas]                               -5995.3333    715.747     -8.376      0.000     -7398.178 -4592.488
# C(TYPE)[T.Sidewalk Cover / Manhole]                          -5193.5977    671.854     -7.730      0.000     -6510.413 -3876.783
# C(TYPE)[T.Sidewalk Repair]                                    1074.9604    666.302      1.613      0.107      -230.973  2380.894
# C(TYPE)[T.Sidewalk Repair (Internal)]                        -6010.8003    667.500     -9.005      0.000     -7319.081 -4702.520
# C(TYPE)[T.Sidewalk Repair (Make Safe)]                       -4949.3692    665.808     -7.434      0.000     -6254.334 -3644.404
# C(TYPE)[T.Sign Repair]                                       -5750.6468    665.911     -8.636      0.000     -7055.813 -4445.480
# C(TYPE)[T.Sign Shop WO]                                      -5174.0618    815.013     -6.348      0.000     -6771.464 -3576.659
# C(TYPE)[T.Snow Removal]                                      -5932.0015    739.612     -8.020      0.000     -7381.621 -4482.382
# C(TYPE)[T.Snow/Ice Control]                                  -5979.4793    700.971     -8.530      0.000     -7353.362 -4605.596
# C(TYPE)[T.Space Savers]                                      -5922.4606    668.783     -8.856      0.000     -7233.256 -4611.666
# C(TYPE)[T.Squalid Living Conditions]                         -4830.7847    697.935     -6.922      0.000     -6198.718 -3462.851
# C(TYPE)[T.Sticker Request]                                   -5984.0451    666.051     -8.984      0.000     -7289.487 -4678.603
# C(TYPE)[T.Street Light Knock Downs]                          -5226.4032    667.742     -7.827      0.000     -6535.159 -3917.648
# C(TYPE)[T.Street Light Longterm Repair]                        1.32e-12   1.11e-12      1.185      0.236     -8.64e-13   3.5e-12
# C(TYPE)[T.Street Light Outages]                              -5006.1171    665.637     -7.521      0.000     -6310.748 -3701.487
# C(TYPE)[T.Street Light Outages (Internal)]                   -5805.1911    682.631     -8.504      0.000     -7143.129 -4467.253
# C(TYPE)[T.StreetLight Pole WO]                               -5302.7530    711.402     -7.454      0.000     -6697.080 -3908.426
# C(TYPE)[T.Student Move-in Issues]                            -5968.4325    681.024     -8.764      0.000     -7303.219 -4633.645
# C(TYPE)[T.Student Overcrowding]                              -4449.5325    834.192     -5.334      0.000     -6084.526 -2814.539
# C(TYPE)[T.Traffic Signal Inspection]                         -5906.2127    666.956     -8.855      0.000     -7213.427 -4598.998
# C(TYPE)[T.Traffic Signal Repair]                             -5894.8315    665.995     -8.851      0.000     -7200.162 -4589.501
# C(TYPE)[T.Transfer Not Completed]                            -6009.2450   1996.366     -3.010      0.003     -9922.066 -2096.424
# C(TYPE)[T.Transportation General Request]                    -4585.0297    671.192     -6.831      0.000     -5900.547 -3269.512
# C(TYPE)[T.Trash on Vacant Lot]                               -3976.3823    670.737     -5.928      0.000     -5291.007 -2661.757
# C(TYPE)[T.Tree Emergencies]                                  -5863.7755    666.444     -8.799      0.000     -7169.987 -4557.564
# C(TYPE)[T.Tree Maintenance Requests]                         -3209.5709    665.850     -4.820      0.000     -4514.618 -1904.524
# C(TYPE)[T.Tree in Park]                                      -3478.7754    681.208     -5.107      0.000     -4813.924 -2143.627
# C(TYPE)[T.Undefined Noise Disturbance]                       -5934.6857    834.192     -7.114      0.000     -7569.679 -4299.692
# C(TYPE)[T.Unit Pricing Wrong/Missing]                        -5914.6368    914.581     -6.467      0.000     -7707.189 -4122.084
# C(TYPE)[T.Unsafe Dangerous Conditions]                       -3531.1609    667.146     -5.293      0.000     -4838.749 -2223.573
# C(TYPE)[T.Unsanitary Conditions - Employees]                 -5938.6447    702.453     -8.454      0.000     -7315.432 -4561.857
# C(TYPE)[T.Unsanitary Conditions - Establishment]             -5889.4816    669.819     -8.793      0.000     -7202.308 -4576.655
# C(TYPE)[T.Unsanitary Conditions - Food]                      -5910.4520    674.299     -8.765      0.000     -7232.059 -4588.845
# C(TYPE)[T.Unsatisfactory Living Conditions]                  -4684.8840    666.045     -7.034      0.000     -5990.313 -3379.455
# C(TYPE)[T.Unsatisfactory Utilities - Electrical  Plumbing]   -5176.6405    685.936     -7.547      0.000     -6521.055 -3832.226
# C(TYPE)[T.Unshoveled Sidewalk]                               -6001.8702    667.969     -8.985      0.000     -7311.070 -4692.670
# C(TYPE)[T.Upgrade Existing Lighting]                         -4552.3237    688.212     -6.615      0.000     -5901.201 -3203.447
# C(TYPE)[T.Utility Call-In]                                   -5977.6331    667.446     -8.956      0.000     -7285.809 -4669.457
# C(TYPE)[T.Utility Casting Repair]                            -4640.0824    675.031     -6.874      0.000     -5963.123 -3317.041
# C(TYPE)[T.Valet Parking Problems]                            -5692.4888    824.019     -6.908      0.000     -7307.543 -4077.435
# C(TYPE)[T.WC Call Log]                                       -6010.6260   1152.602     -5.215      0.000     -8269.694 -3751.558
# C(TYPE)[T.Walk-In Service Inquiry]                           -5395.6448   1073.014     -5.028      0.000     -7498.723 -3292.567
# C(TYPE)[T.Water in Gas - High Priority]                      -5942.3885   1274.250     -4.663      0.000     -8439.882 -3444.895
# C(TYPE)[T.Watermain Break]                                   -5714.5081    694.401     -8.229      0.000     -7075.515 -4353.501
# C(TYPE)[T.Work Hours-Loud Noise Complaints]                  -5746.0955    672.497     -8.544      0.000     -7064.171 -4428.020
# C(TYPE)[T.Work w/out Permit]                                 -3206.2866    667.139     -4.806      0.000     -4513.860 -1898.713
# C(TYPE)[T.Working Beyond Hours]                              -3768.1214    671.180     -5.614      0.000     -5083.615 -2452.628
# C(TYPE)[T.Yardwaste Asian Longhorned Beetle Affected Area]   -5983.6386   1274.250     -4.696      0.000     -8481.132 -3486.145
# C(TYPE)[T.Zoning]                                            -2705.4776    679.177     -3.983      0.000     -4036.646 -1374.309
# ==============================================================================
# Omnibus:                   347583.669   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         55168693.001
# Skew:                           6.177   Prob(JB):                         0.00
# Kurtosis:                      68.820   Cond. No.                     1.05e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.79e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
get_rmse(est)
# Out:
# 1881.5539142475611

# %% [markdown]
# ## Getting CV R^2 score, but for ea fold
#
# Just using $R^2$ for now since it's the default for `sklearn`. Will want to try out adjusted $R^2$ and RMSE as well.

# %%
vectorizer = CountVectorizer()
vectorizer.fit_transform(df['TYPE']); # I need to have all the columns be all the possible categories from _both_ train and test data

# %%
ss = ShuffleSplit(n_splits=5, test_size=0.2, random_state=300)

# %%
pipe = make_pipeline(LinearRegression())
# pipe = make_pipeline(StandardScaler(), LinearRegression()) # StdScaler doesn't work for some reason
# pipe = make_pipeline(LabelEncoder(), OneHotEncoder(), LinearRegression())

# %% [raw]
# TODO: I don't put the CountVectorizer into the pipeline, right?

# %%
training_scores = []
test_scores = []

for CV_train_index, CV_test_index in ss.split(y_train):
    X_CV_train = vectorizer.transform(X_train.iloc[CV_train_index]['TYPE'])
    X_CV_test = vectorizer.transform(X_train.iloc[CV_test_index]['TYPE'])
    y_CV_train = y_train.iloc[CV_train_index]
    y_CV_test = y_train.iloc[CV_test_index]
    
    pipe.fit(X_CV_train, y_CV_train)
    training_score = pipe.score(X_CV_train, y_CV_train)
    test_score = pipe.score(X_CV_test, y_CV_test)
    training_scores += [training_score]
    test_scores += [test_score]
    print "Training: {}. Test: {}".format(training_score, test_score)
# Out:
# Training: 0.251190728986. Test: 0.244443794726
# Training: 0.25098114034. Test: 0.245562044148
# Training: 0.250661088013. Test: 0.246838181334
# Training: 0.250889657331. Test: 0.245313621299
# Training: 0.250496518478. Test: 0.247290981624

# %% [raw]
# First check: do we get the same kind of R^2 score of around 0.25?
# yes

# %% [raw]
# Are we in high bias or high variance situation?
# Training error is _slightly_ higher than test error. To the extent that this difference is "significant", that would imply a high bias situation. To the extent that the difference is not significant, we are in neither a high bias nor high variance situation.
#
# On a side note, all the errors in each of the folds are similar, so ShuffleSplit did a good job!

# %% [markdown]
# ## Let's check the performance of our baseline model on the test data
#
# I predict that it will be pretty similar to the CV performances: ~24% $R^2$.

# %%
pipe.score(vectorizer.transform(X_test['TYPE']), y_test)
# Out:
# 0.24201144067182326

# %% [markdown]
# And indeed it is 0.24.

# %% [markdown]
# ## Playing around w a couple more options
# - StdScaler
# - `Reason` instead of `TYPE`
# - higher-order polynomials
#
# ### First: StdScaler

# %%
pipe = make_pipeline(StandardScaler(with_mean=False), LinearRegression()) # StdScaler doesn't work for some reason
ss = ShuffleSplit(n_splits=5, test_size=0.2, random_state=300)

# %%
training_scores = []
test_scores = []

for CV_train_index, CV_test_index in ss.split(y_train):
    X_CV_train = vectorizer.transform(X_train.iloc[CV_train_index]['TYPE'])
    X_CV_test = vectorizer.transform(X_train.iloc[CV_test_index]['TYPE'])
    y_CV_train = y_train.iloc[CV_train_index]
    y_CV_test = y_train.iloc[CV_test_index]
    
    pipe.fit(X_CV_train, y_CV_train)
    training_score = pipe.score(X_CV_train, y_CV_train)
    test_score = pipe.score(X_CV_test, y_CV_test)
    training_scores += [training_score]
    test_scores += [test_score]
    print "Training: {}. Test: {}".format(training_score, test_score)
# Out:
# Training: 0.251190729522. Test: 0.244376787574
# Training: 0.250981140706. Test: 0.245561964383
# Training: 0.250661088981. Test: 0.2468307821
# Training: 0.250889657881. Test: 0.245296219324
# Training: 0.250496519272. Test: 0.247254285959

# %% [markdown]
# I would expect higher $R^2$ scores than w/o StdScaler.
#
# Instead, they're about the same. I guess this means ShuffleSplit really shuffled the rows well?
#
# Update: Now that I think about it, since I'm only using one feature, scaling doesn't come into play. So it makes sense that I'd get similar CV $R^2$ values.
#
# ### Second: Trying `Reason`, w/o StdScaler

# %%
pipe = make_pipeline(LinearRegression()) # StdScaler doesn't work for some reason
ss = ShuffleSplit(n_splits=5, test_size=0.2, random_state=300)

# %%
training_scores = []
test_scores = []

for CV_train_index, CV_test_index in ss.split(y_train):
    X_CV_train = vectorizer.transform(X_train.iloc[CV_train_index]['REASON'])
    X_CV_test = vectorizer.transform(X_train.iloc[CV_test_index]['REASON'])
    y_CV_train = y_train.iloc[CV_train_index]
    y_CV_test = y_train.iloc[CV_test_index]
    
    pipe.fit(X_CV_train, y_CV_train)
    training_score = pipe.score(X_CV_train, y_CV_train)
    test_score = pipe.score(X_CV_test, y_CV_test)
    training_scores += [training_score]
    test_scores += [test_score]
    print "Training: {}. Test: {}".format(training_score, test_score)
# Out:
# Training: 0.050364299692. Test: 0.0528208754389
# Training: 0.0511371522887. Test: 0.0498099354244
# Training: 0.0512894654362. Test: 0.0492466901145
# Training: 0.0505269903012. Test: 0.0522024353821
# Training: 0.0505914157316. Test: 0.0519740845286

# %% [markdown]
# Looks like `Reason` has even less signal than `TYPE`. This makes sense, since `Reason` is more broad than `TYPE`.
#
# ## Third: higher-order polynomials
#
# Doesn't make sense to use higher-order polynomials when the values are only ever 1 or 0. This will just add more columns without adding more signal.
