# %%
from __future__ import division
import pandas as pd
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
# from tqdm import tqdm

rcParams['figure.figsize'] = 20, 5
warnings.filterwarnings("ignore", category=DeprecationWarning)
sns.set_style("whitegrid")
sns.set_context("poster")

from scipy.sparse import csr_matrix
from zipcode_mapping import zipcode_mapping

# %%
df = pd.read_pickle('../data/data_w_transformed_census_and_removed_invalid_rows_and_cols_and_fixed_zips_and_descs_and_dropped_latlongs.pkl')
df.shape
# Out:
# (744372, 37)

# %% [markdown]
# # Preprocessing

# %%
df.Property_Type = df.Property_Type.fillna('other')
df.Property_ID = df.Property_ID.fillna('other')

# %%
cols_to_drop = [
    'CASE_ENQUIRY_ID',
    'OPEN_DT',
    'TARGET_DT',
    'CLOSED_DT',
    'CASE_TITLE',
    'SUBJECT',
    'neighborhood',
    'LOCATION_STREET_NAME',
    'LATITUDE',
    'LONGITUDE',
    'tract_and_block_group',
    'is_issue_unresolved'
]

# %%
new_df = df.drop(cols_to_drop, axis=1)

# %%
new_df.head(1).T
# Out:
#                                                            905223
# REASON                           Enforcement & Abandoned Vehicles
# TYPE                                          Parking Enforcement
# Department                                                   BTDT
# SubmittedPhoto                                              False
# Property_Type                                             Address
# Property_ID                                                 43071
# Source                                       Citizens Connect App
# race_white                                               0.550562
# race_black                                               0.152118
# race_asian                                                      0
# race_hispanic                                            0.278306
# race_other                                              0.0190147
# poverty_pop_below_poverty_level                             0.135
# poverty_pop_w_public_assistance                                 0
# poverty_pop_w_food_stamps                                  0.1325
# poverty_pop_w_ssi                                          0.0575
# COMPLETION_TIME                                               NaN
# school                                               20_bachelors
# housing                                                       own
# bedroom                                                         3
# value                                                      350000
# rent                                                         2250
# income                                                      87500
# zipcode                                                      2131
# neighborhood_from_zip                                  Roslindale

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ## Dummifying

# %%
def dummify_cols_and_baselines(df, cols):
    baseline_cols = []
    
    for i, column in enumerate(cols):
        baseline = sorted(df[column].unique())[-1]
        print baseline, 'is baseline', i, len(cols)
        baseline_cols += [baseline]
        dummy = pd.get_dummies(df[column]).rename(columns=lambda x: column+'_'+str(x)).iloc[:,0:len(df[column].unique())-1]
        df = df.drop(column, axis=1) #Why not inplace? because if we do inplace, it will affect the df directly
        df = pd.concat([df, dummy], axis=1)
        
    return df, baseline_cols

# %%
def dummify(df, column):
    # from Darren's linear regression slides
    print '{} is your baseline'.format(sorted(df[column].unique())[-1])
    dummy = pd.get_dummies(df[column]).rename(columns=lambda x: column+'_'+str(x)).iloc[:,0:len(df[column].unique())-1]
    df = df.drop(column,axis=1) #Why not inplace? because if we do inplace, it will affect the df directly
    return pd.concat([df,dummy],axis=1)

# %%
df.school.drop_duplicates()
# Out:
# 905223                 20_bachelors
# 905346                15_hs_diploma
# 905604    18_some_college_no_degree
# 905264                19_associates
# 905398                   21_masters
# 905369                13_11th_grade
# 905117     14_12th_grade_no_diploma
# 903543                  8_6th_grade
# 903909                       0_none
# 902859       22_professional_school
# 902313                 11_9th_grade
# Name: school, dtype: object

# %%
# 887332 2011-07-01 12:00:42            Missed Recycling: District 06
# 555172 2011-07-08 10:26:28              Sidewalk Repair (Make Safe)
# 238818 2011-07-08 10:44:08                          Rodent Activity
# 238819 2011-07-08 10:44:08                          Rodent Activity
# 581905 2011-07-11 12:13:25                          Utility Call-In
# 346396 2011-07-05 09:42:04                          Sticker Request
# 189214 2011-07-01 06:50:29                      Highway Maintenance
# 189213 2011-07-01 06:50:29                      Highway Maintenance
# 38399  2011-07-01 06:44:55                      Pick up Dead Animal
# 38400  2011-07-01 06:44:55                      Pick up Dead Animal
# 867668 2011-08-23 10:33:03                     Street Light Outages
# 867669 2011-08-23 10:33:03                     Street Light Outages
# 341713 2011-10-17 12:33:28  New Sign  Crosswalk or Pavement Marking
# 341714 2011-10-17 12:33:28  New Sign  Crosswalk or Pavement Marking
# 592091 2011-07-05 09:16:10                             Notification
# 21650  2011-07-01 06:12:38                      Highway Maintenance
# 21651  2011-07-01 06:12:38                      Highway Maintenance
# 790373 2011-07-22 04:13:45                     Street Light Outages
# 790372 2011-07-22 04:13:45                     Street Light Outages
# 237559 2011-08-01 03:21:46  New Sign  Crosswalk or Pavement Marking
# 237560 2011-08-01 03:21:46  New Sign  Crosswalk or Pavement Marking
# 604996 2011-07-01 06:12:43              Schedule a Bulk Item Pickup
# 700066 2011-07-01 05:06:58                     Street Light Outages
# 700067 2011-07-01 05:06:58                     Street Light Outages
#
#                                   SUBJECT                             REASON  \
# 905223  Transportation - Traffic Division   Enforcement & Abandoned Vehicles
# 905346            Mayor's 24 Hour Hotline                       Notification
# 905302            Public Works Department                    Street Cleaning
# 905507            Public Works Department                    Street Cleaning
# 905217            Public Works Department                    Street Cleaning
# 905594            Public Works Department  Administrative & General Requests
# 905458  Transportation - Traffic Division   Enforcement & Abandoned Vehicles
# 905543            Public Works Department                    Street Cleaning
# 905604  Transportation - Traffic Division   Enforcement & Abandoned Vehicles
# 905488  Transportation - Traffic Division   Enforcement & Abandoned Vehicles
# 905582  Transportation - Traffic Division   Enforcement & Abandoned Vehicles
# 905595  Transportation - Traffic Division   Enforcement & Abandoned Vehicles
# 905545  Transportation - Traffic Division   Enforcement & Abandoned Vehicles
# 905313  Transportation - Traffic Division   Enforcement & Abandoned Vehicles
# 905425            Public Works Department                    Street Cleaning
# 905549            Public Works Department                    Street Cleaning
# 905480  Transportation - Traffic Division   Enforcement & Abandoned Vehicles
# 905518            Public Works Department  Administrative & General Requests
# 905491            Public Works Department                    Street Cleaning
# 905328            Public Works Department                         Sanitation
# 905626  Transportation - Traffic Division   Enforcement & Abandoned Vehicles
# 905647            Public Works Department  Administrative & General Requests
# 905618              Inspectional Services                            Housing
# 905225            Public Works Department                Highway Maintenance
# 905235            Public Works Department  Administrative & General Requests
# 905316            Public Works Department  Administrative & General Requests
# 905379            Public Works Department  Administrative & General Requests
# 905584  Transportation - Traffic Division   Enforcement & Abandoned Vehicles
# 905558  Transportation - Traffic Division   Enforcement & Abandoned Vehicles
# 905264            Public Works Department  Administrative & General Requests
# ...                                   ...                                ...
# 226130            Public Works Department                    Street Cleaning
# 828744            Public Works Department                         Sanitation
# 450951            Public Works Department                         Sanitation
# 332424            Public Works Department                         Sanitation
# 367325            Public Works Department                          Recycling
# 887333            Public Works Department                         Sanitation
# 887332            Public Works Department                         Sanitation
# 555172            Public Works Department                Highway Maintenance
# 238818              Inspectional Services             Environmental Services
# 238819              Inspectional Services             Environmental Services
# 581905            Public Works Department                Highway Maintenance
# 346396            Public Works Department                          Recycling
# 189214            Public Works Department                Highway Maintenance
# 189213            Public Works Department                Highway Maintenance
# 38399             Public Works Department                    Street Cleaning
# 38400             Public Works Department                    Street Cleaning
# 867668            Public Works Department                      Street Lights
# 867669            Public Works Department                      Street Lights
# 341713  Transportation - Traffic Division                    Signs & Signals
# 341714  Transportation - Traffic Division                    Signs & Signals
# 592091            Mayor's 24 Hour Hotline                       Notification
# 21650             Public Works Department                Highway Maintenance
# 21651             Public Works Department                Highway Maintenance
# 790373            Public Works Department                      Street Lights
# 790372            Public Works Department                      Street Lights
# 237559  Transportation - Traffic Division                    Signs & Signals
# 237560  Transportation - Traffic Division                    Signs & Signals
# 604996            Public Works Department                         Sanitation
# 700066            Public Works Department                      Street Lights
# 700067            Public Works Department                      Street Lights
#
#                                                TYPE Department SubmittedPhoto  \
# 905223                          Parking Enforcement       BTDT          False
# 905346                                 Notification       INFO          False
# 905302                     Request for Snow Plowing       PWDx          False
# 905507                     Request for Snow Plowing       PWDx          False
# 905217                     Request for Snow Plowing       PWDx          False
# 905594                         Misc. Snow Complaint       PARK          False
# 905458                          Parking Enforcement       BTDT           True
# 905543                     Request for Snow Plowing       PWDx          False
# 905604                           Abandoned Vehicles       BTDT           True
# 905488                          Parking Enforcement       BTDT           True
# 905582                          Parking Enforcement       BTDT           True
# 905595                          Parking Enforcement       BTDT          False
# 905545                          Parking Enforcement       BTDT           True
# 905313                          Parking Enforcement       BTDT           True
# 905425                     Request for Snow Plowing       PWDx           True
# 905549                     Request for Snow Plowing       PWDx          False
# 905480                          Parking Enforcement       BTDT          False
# 905518                         Misc. Snow Complaint       BTDT           True
# 905491                     Request for Snow Plowing       PWDx           True
# 905328                                 Space Savers       PWDx          False
# 905626                          Parking Enforcement       BTDT           True
# 905647                         Misc. Snow Complaint       PWDx          False
# 905618               Heat - Excessive  Insufficient        ISD          False
# 905225                  Sidewalk Repair (Make Safe)       PWDx          False
# 905235                         Misc. Snow Complaint       PWDx          False
# 905316                         Misc. Snow Complaint       PWDx          False
# 905379                         Misc. Snow Complaint       PWDx          False
# 905584                          Parking Enforcement       BTDT          False
# 905558                          Parking Enforcement       BTDT          False
# 905264                 Public Works General Request       PWDx          False
# ...                                             ...        ...            ...
# 226130                          Pick up Dead Animal       PWDx          False
# 828744                  Schedule a Bulk Item Pickup       PWDx          False
# 450951                  Schedule a Bulk Item Pickup       PWDx          False
# 332424                  Schedule a Bulk Item Pickup       PWDx          False
# 367325                   Request for Recycling Cart       PWDx          False
# 887333  Missed Trash/Recycling/Yard Waste/Bulk Item       PWDx          False
# 887332  Missed Trash/Recycling/Yard Waste/Bulk Item       PWDx          False
# 555172                  Sidewalk Repair (Make Safe)       PWDx          False
# 238818                              Rodent Activity        ISD          False
# 238819                              Rodent Activity        ISD          False
# 581905                              Utility Call-In       PWDx          False
# 346396                              Sticker Request       PWDx          False
# 189214                          Highway Maintenance       PWDx          False
# 189213                          Highway Maintenance       PWDx          False
# 38399                           Pick up Dead Animal       PWDx          False
# 38400                           Pick up Dead Animal       PWDx          False
# 867668                         Street Light Outages       PWDx          False
# 867669                         Street Light Outages       PWDx          False
# 341713      New Sign  Crosswalk or Pavement Marking       BTDT          False
# 341714      New Sign  Crosswalk or Pavement Marking       BTDT          False
# 592091                                 Notification       INFO          False
# 21650                           Highway Maintenance       PWDx          False
# 21651                           Highway Maintenance       PWDx          False
# 790373                         Street Light Outages       PWDx          False
# 790372                         Street Light Outages       PWDx          False
# 237559      New Sign  Crosswalk or Pavement Marking       BTDT          False
# 237560      New Sign  Crosswalk or Pavement Marking       BTDT          False
# 604996                  Schedule a Bulk Item Pickup       PWDx          False
# 700066                         Street Light Outages       PWDx          False
# 700067                         Street Light Outages       PWDx          False
#
#                     ...               school_0_none school_11_9th_grade  \
# 905223              ...                           0                   0
# 905346              ...                           0                   0
# 905302              ...                           0                   0
# 905507              ...                           0                   0
# 905217              ...                           0                   0
# 905594              ...                           0                   0
# 905458              ...                           0                   0
# 905543              ...                           0                   0
# 905604              ...                           0                   0
# 905488              ...                           0                   0
# 905582              ...                           0                   0
# 905595              ...                           0                   0
# 905545              ...                           0                   0
# 905313              ...                           0                   0
# 905425              ...                           0                   0
# 905549              ...                           0                   0
# 905480              ...                           0                   0
# 905518              ...                           0                   0
# 905491              ...                           0                   0
# 905328              ...                           0                   0
# 905626              ...                           0                   0
# 905647              ...                           0                   0
# 905618              ...                           0                   0
# 905225              ...                           0                   0
# 905235              ...                           0                   0
# 905316              ...                           0                   0
# 905379              ...                           0                   0
# 905584              ...                           0                   0
# 905558              ...                           0                   0
# 905264              ...                           0                   0
# ...                 ...                         ...                 ...
# 226130              ...                           0                   0
# 828744              ...                           0                   0
# 450951              ...                           0                   0
# 332424              ...                           0                   0
# 367325              ...                           0                   0
# 887333              ...                           0                   0
# 887332              ...                           0                   0
# 555172              ...                           0                   0
# 238818              ...                           0                   0
# 238819              ...                           0                   0
# 581905              ...                           0                   0
# 346396              ...                           0                   0
# 189214              ...                           0                   0
# 189213              ...                           0                   0
# 38399               ...                           0                   0
# 38400               ...                           0                   0
# 867668              ...                           0                   0
# 867669              ...                           0                   0
# 341713              ...                           0                   0
# 341714              ...                           0                   0
# 592091              ...                           0                   0
# 21650               ...                           0                   0
# 21651               ...                           0                   0
# 790373              ...                           0                   0
# 790372              ...                           0                   0
# 237559              ...                           0                   0
# 237560              ...                           0                   0
# 604996              ...                           0                   0
# 700066              ...                           0                   0
# 700067              ...                           0                   0
#
#        school_13_11th_grade school_14_12th_grade_no_diploma  \
# 905223                    0                               0
# 905346                    0                               0
# 905302                    0                               0
# 905507                    0                               0
# 905217                    0                               0
# 905594                    0                               0
# 905458                    0                               0
# 905543                    0                               0
# 905604                    0                               0
# 905488                    0                               0
# 905582                    0                               0
# 905595                    0                               0
# 905545                    0                               0
# 905313                    0                               0
# 905425                    0                               0
# 905549                    0                               0
# 905480                    0                               0
# 905518                    0                               0
# 905491                    0                               0
# 905328                    0                               0
# 905626                    0                               0
# 905647                    0                               0
# 905618                    0                               0
# 905225                    0                               0
# 905235                    0                               0
# 905316                    0                               0
# 905379                    0                               0
# 905584                    0                               0
# 905558                    0                               0
# 905264                    0                               0
# ...                     ...                             ...
# 905558                    0                   1                  0
# 905264                    1                   0                  0
# ...                     ...                 ...                ...
# 226130                    0                   0                  0
# 828744                    0                   1                  0
# 450951                    0                   1                  0
# 332424                    0                   1                  0
# 367325                    0                   1                  0
# 887333                    0                   1                  0
# 887332                    0                   1                  0
# 555172                    0                   1                  0
# 238818                    0                   1                  0
# 238819                    0                   1                  0
# 581905                    0                   0                  0
# 346396                    0                   0                  0
# 189214                    0                   1                  0
# 189213                    0                   1                  0
# 38399                     0                   1                  0
# 38400                     0                   1                  0
# 867668                    0                   0                  0
# 867669                    0                   0                  0
# 341713                    0                   1                  0
# 341714                    0                   1                  0
# 592091                    0                   0                  1
# 21650                     0                   1                  0
# 21651                     0                   1                  0
# 790373                    0                   0                  0
# 790372                    0                   0                  0
# 237559                    0                   0                  1
# 237560                    0                   0                  1
# 604996                    0                   1                  0
# 700066                    0                   0                  0
# 700067                    0                   0                  0
#
#         school_22_professional_school
# 905223                              0
# 905346                              0
# 905302                              0
# 905507                              0
# 905217                              0
# 905594                              0
# 905458                              0
# 905543                              0
# 905604                              0
# 905488                              0
# 905582                              0
# 905595                              0
# 905545                              0
# 905313                              0
# 905425                              0
# 905549                              0
# 905480                              0
# 905518                              0
# 905491                              0
# 905328                              0
# 905626                              0
# 905647                              0
# 905618                              0
# 905225                              0
# 905235                              0
# 905316                              0
# 905379                              0
# 905584                              0
# 905558                              0
# 905264                              0
# ...                               ...
# 226130                              0
# 828744                              0
# 450951                              0
# 332424                              0
# 367325                              0
# 887333                              0
# 887332                              0
# 555172                              0
# 238818                              0
# 238819                              0
# 581905                              0
# 346396                              0
# 189214                              0
# 189213                              0
# 38399                               0
# 38400                               0
# 867668                              0
# 867669                              0
# 341713                              0
# 341714                              0
# 592091                              0
# 21650                               0
# 21651                               0
# 790373                              0
# 790372                              0
# 237559                              0
# 237560                              0
# 604996                              0
# 700066                              0
# 700067                              0
#
# [744372 rows x 46 columns]

# %%
cols_to_dummify = new_df.dtypes[new_df.dtypes == object].index
cols_to_dummify
# Out:
# Index([u'REASON', u'TYPE', u'Department', u'Property_Type', u'Property_ID',
#        u'Source', u'school', u'housing', u'neighborhood_from_zip'],
#       dtype='object')

# %%
df_dummified, baseline_cols = dummify_cols_and_baselines(df, cols_to_dummify)
# Out:
# Weights and Measures is baseline 0 9
# Zoning is baseline 1 9
# PWDx is baseline 2 9
# other is baseline 3 9
# other is baseline 4 9

# %% [markdown]
# ## Run model

# %%
from sklearn.cross_validation import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LassoCV
from sklearn.cross_validation import ShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import FunctionTransformer

# %%
log_transform = FunctionTransformer(pd.np.log10)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df_dummified.drop('COMPLETION_TIME', axis=1), 
    pd.np.log10(df_dummified.COMPLETION_TIME), 
    test_size=0.2, 
    random_state=300
)

# %%
pipe = make_pipeline(LassoCV(verbose=100))
# cv = ShuffleSplit(X_train.shape[0], n_iter=5, test_size=0.2, random_state=300)

# %%
params = {}
model = GridSearchCV(pipe, param_grid=params, n_jobs=-1, cv=5, verbose=100)
model.fit(aa, y_train);
