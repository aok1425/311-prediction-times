# %% [markdown]
# ## Objective
#
# Use Decision Tree + pruning to see if the data is non-linear, and to incorporate lat/long points. Try to improve upon $R^2$ of 0.56 from Linear Regression with outliers removed.

# %%
from __future__ import division
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline
from scipy.stats import beta, binom

rcParams['figure.figsize'] = 20, 5
warnings.filterwarnings("ignore", category=DeprecationWarning)
sns.set_style("whitegrid")
sns.set_context("poster")

from helper_functions import dummify_cols_and_baselines, make_alphas, remove_outliers_by_type

# %%
df_orig = pd.read_pickle('../data/data_from_remove_from_dataset.pkl')
df_orig.shape
# Out:
# (516406, 40)

# %% [markdown]
# ## Removing outliers
#
# A standard procedure is to remove values further than 3 standard deviations from the mean. Since I have so many low values and some very high values, I anecdotally think that the low values are very likely to be true, and the high values not so much.
#
# So, I will remove values further than 3 SDs from the median, by type.
#
# Ideally, I would take into account the time dimension. I would like to do so given more time.

# %%
df_outliers_removed = remove_outliers_by_type(df_orig, y_col='COMPLETION_HOURS_LOG_10')
df_outliers_removed.shape
# Out:
# helper_functions.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   group[pd.np.abs(group - group.median()) > stds * group.std()] = pd.np.nan
# /home/ec2-user/anaconda2/lib/python2.7/site-packages/pandas/core/frame.py:2454: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._where(-key, value, inplace=True)
# (508653, 40)

# %% [markdown]
# I'm removing ~1.5% of my rows.

# %% [markdown]
# ## Choosing columns

# %%
df_orig.head(1).loc[:, :]
# Out:
#         CASE_ENQUIRY_ID             OPEN_DT           CLOSED_DT  \
# 905425     101001983786 2017-01-07 10:51:37 2017-01-07 11:46:43
#
#                             TYPE SubmittedPhoto  LOCATION_ZIPCODE  \
# 905425  Request for Snow Plowing           True            2124.0
#
#        Property_Type  LATITUDE  LONGITUDE                Source  \
# 905425       Address   42.2809    -71.068  Citizens Connect App
#
#              ...       housing  housing_std_dev bedroom  bedroom_std_dev  \
# 905425       ...           own        26.870058       3        61.512329
#
#            value  value_std_dev  rent  rent_std_dev  income  income_std_dev
# 905425  350000.0      20.979404  1750     19.162161  112500        28.61672
#
# [1 rows x 40 columns]

# %%
cols_orig_dataset = ['COMPLETION_HOURS_LOG_10', 'TYPE', 'SubmittedPhoto', 'Property_Type', 'Source', 'neighborhood_from_zip']
cols_census = ['race_white',
     'race_black',
     'race_asian',
     'race_hispanic',
     'race_other',
     'poverty_pop_below_poverty_level',
     'earned_income_per_capita',
     'poverty_pop_w_public_assistance',
     'poverty_pop_w_food_stamps',
     'poverty_pop_w_ssi',
     'school',
     'school_std_dev',
     'housing',
     'housing_std_dev',
     'bedroom',
     'bedroom_std_dev',
     'value',
     'value_std_dev',
     'rent',
     'rent_std_dev',
     'income',
     'income_std_dev']
cols_engineered = ['queue_wk', 'queue_wk_open', 'is_description']
cols_for_trees = ['LATITUDE', 'LONGITUDE']

# %%
df = df_outliers_removed[cols_orig_dataset + cols_census + cols_engineered + cols_for_trees]

# %% [markdown]
# ## Dummify

# %%
cols_to_dummify = df.dtypes[df.dtypes == object].index
cols_to_dummify
# Out:
# Index([u'TYPE', u'Property_Type', u'Source', u'neighborhood_from_zip',
#        u'school', u'housing'],
#       dtype='object')

# %%
df_dummified, baseline_cols = dummify_cols_and_baselines(df, cols_to_dummify)
# Out:
# Zoning is baseline 0 6
# other is baseline 1 6
# Twitter is baseline 2 6
# West Roxbury is baseline 3 6
# 8_6th_grade is baseline 4 6
# rent is baseline 5 6

# %%
df_dummified.shape
# Out:
# (508653, 255)

# %% [markdown]
# ## Running model

# %%
from sklearn.cross_validation import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.cross_validation import ShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df_dummified.drop('COMPLETION_HOURS_LOG_10', axis=1), 
    df_dummified.COMPLETION_HOURS_LOG_10, 
    test_size=0.2, 
    random_state=300
)

# %%
pipe = make_pipeline(DecisionTreeRegressor(splitter='random'))

# %%
cv = ShuffleSplit(X_train.shape[0], n_iter=1, test_size=0.2, random_state=300)

# %%
params = {'decisiontreeregressor__max_depth': binom(100, 0.83),
          'decisiontreeregressor__min_samples_split': beta(1, 50), # http://homepage.divms.uiowa.edu/~mbognar/applets/beta.html
          'decisiontreeregressor__min_samples_leaf': beta(3, 40)}
model = RandomizedSearchCV(pipe, param_distributions=params, n_jobs=-1, cv=cv, verbose=100, n_iter=100)
model.fit(X_train, y_train);
# Out:
# Fitting 1 folds for each of 100 candidates, totalling 100 fits
# Pickling array (shape=(254,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to new file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to new file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to new file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to new file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to new file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# [CV] decisiontreeregressor__max_depth=88, decisiontreeregressor__min_samples_leaf=0.0499356420882, decisiontreeregressor__min_samples_split=0.0155639871066
# Pickling array (shape=(406922,), dtype=object).
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).
# [CV] decisiontreeregressor__max_depth=83, decisiontreeregressor__min_samples_leaf=0.128912194188, decisiontreeregressor__min_samples_split=0.0195558003626
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).
# [CV] decisiontreeregressor__max_depth=84, decisiontreeregressor__min_samples_leaf=0.105409789092, decisiontreeregressor__min_samples_split=0.0749271164526
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).
# [CV] decisiontreeregressor__max_depth=85, decisiontreeregressor__min_samples_leaf=0.102885729753, decisiontreeregressor__min_samples_split=0.0073160863575
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).
# [CV] decisiontreeregressor__max_depth=81, decisiontreeregressor__min_samples_leaf=0.11528233332, decisiontreeregressor__min_samples_split=0.0178088352772
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# [CV] decisiontreeregressor__max_depth=81, decisiontreeregressor__min_samples_leaf=0.106588554765, decisiontreeregressor__min_samples_split=0.0193025911741
# Pickling array (shape=(406922,), dtype=object).
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).[CV] decisiontreeregressor__max_depth=77, decisiontreeregressor__min_samples_leaf=0.119922059299, decisiontreeregressor__min_samples_split=0.0289224612845
#
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).
# [CV] decisiontreeregressor__max_depth=87, decisiontreeregressor__min_samples_leaf=0.0953296051105, decisiontreeregressor__min_samples_split=0.030055545726
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# [CV]  decisiontreeregressor__max_depth=88, decisiontreeregressor__min_samples_leaf=0.0499356420882, decisiontreeregressor__min_samples_split=0.0155639871066, score=0.175032, total=   9.5s
# [CV]  decisiontreeregressor__max_depth=83, decisiontreeregressor__min_samples_leaf=0.128912194188, decisiontreeregressor__min_samples_split=0.0195558003626, score=0.038857, total=   7.9s
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   16.2s
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).
# [CV] decisiontreeregressor__max_depth=85, decisiontreeregressor__min_samples_leaf=0.0162630338545, decisiontreeregressor__min_samples_split=0.00741915170553
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).[CV]  decisiontreeregressor__max_depth=84, decisiontreeregressor__min_samples_leaf=0.105409789092, decisiontreeregressor__min_samples_split=0.0749271164526, score=0.040293, total=   8.5s
# [CV] decisiontreeregressor__max_depth=84, decisiontreeregressor__min_samples_leaf=0.163015255499, decisiontreeregressor__min_samples_split=0.00661057568795
#
# [Parallel(n_jobs=-1)]: Done   3 out of 100 | elapsed:   18.6s remaining: 10.0min
# Pickling array (shape=(406922,), dtype=object).
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [CV]  decisiontreeregressor__max_depth=85, decisiontreeregressor__min_samples_leaf=0.102885729753, decisiontreeregressor__min_samples_split=0.0073160863575, score=0.040293, total=   8.3s
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).[CV] decisiontreeregressor__max_depth=80, decisiontreeregressor__min_samples_leaf=0.117760744189, decisiontreeregressor__min_samples_split=0.0268507766312
#
# Pickling array (shape=(406922,), dtype=object).
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# [CV]  decisiontreeregressor__max_depth=81, decisiontreeregressor__min_samples_leaf=0.11528233332, decisiontreeregressor__min_samples_split=0.0178088352772, score=0.039070, total=   7.9s
# Pickling array (shape=(406922,), dtype=object).[Parallel(n_jobs=-1)]: Done   5 out of 100 | elapsed:   21.2s remaining:  6.7min
#
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).[CV] decisiontreeregressor__max_depth=75, decisiontreeregressor__min_samples_leaf=0.0805103573721, decisiontreeregressor__min_samples_split=0.0308407977803
#
# Pickling array (shape=(406922,), dtype=object).
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# [CV]  decisiontreeregressor__max_depth=81, decisiontreeregressor__min_samples_leaf=0.106588554765, decisiontreeregressor__min_samples_split=0.0193025911741, score=0.040293, total=   8.1s
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).[CV] decisiontreeregressor__max_depth=87, decisiontreeregressor__min_samples_leaf=0.0480780910344, decisiontreeregressor__min_samples_split=0.0281787101542
#
# Pickling array (shape=(406922,), dtype=object).
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# [CV]  decisiontreeregressor__max_depth=77, decisiontreeregressor__min_samples_leaf=0.119922059299, decisiontreeregressor__min_samples_split=0.0289224612845, score=0.039070, total=   8.0s
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# [Parallel(n_jobs=-1)]: Done   7 out of 100 | elapsed:   24.8s remaining:  5.5min
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).[CV] decisiontreeregressor__max_depth=86, decisiontreeregressor__min_samples_leaf=0.073184223593, decisiontreeregressor__min_samples_split=0.0665688701074
#
# Pickling array (shape=(406922,), dtype=object).
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# [CV]  decisiontreeregressor__max_depth=87, decisiontreeregressor__min_samples_leaf=0.0953296051105, decisiontreeregressor__min_samples_split=0.030055545726, score=0.040293, total=   8.4s
# [CV] decisiontreeregressor__max_depth=79, decisiontreeregressor__min_samples_leaf=0.0507810916207, decisiontreeregressor__min_samples_split=0.00303966523363
# Pickling array (shape=(406922,), dtype=object).
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).
# [CV] decisiontreeregressor__max_depth=82, decisiontreeregressor__min_samples_leaf=0.060259667285, decisiontreeregressor__min_samples_split=0.00640376164113
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# [CV]  decisiontreeregressor__max_depth=84, decisiontreeregressor__min_samples_leaf=0.163015255499, decisiontreeregressor__min_samples_split=0.00661057568795, score=0.022350, total=   7.6s
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).[Parallel(n_jobs=-1)]: Done   9 out of 100 | elapsed:   30.4s remaining:  5.1min
#
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# [CV] decisiontreeregressor__max_depth=86, decisiontreeregressor__min_samples_leaf=0.0678524473481, decisiontreeregressor__min_samples_split=0.00105676181232
# Pickling array (shape=(406922,), dtype=object).
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).[CV]  decisiontreeregressor__max_depth=80, decisiontreeregressor__min_samples_leaf=0.117760744189, decisiontreeregressor__min_samples_split=0.0268507766312, score=0.039070, total=   8.0s
# [CV] decisiontreeregressor__max_depth=80, decisiontreeregressor__min_samples_leaf=0.08152939084, decisiontreeregressor__min_samples_split=0.00340779110561
# [CV]  decisiontreeregressor__max_depth=85, decisiontreeregressor__min_samples_leaf=0.0162630338545, decisiontreeregressor__min_samples_split=0.00741915170553, score=0.313319, total=  11.9s
#
# [Parallel(n_jobs=-1)]: Done  11 out of 100 | elapsed:   32.9s remaining:  4.4min
# Pickling array (shape=(406922,), dtype=object).
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).[CV] decisiontreeregressor__max_depth=82, decisiontreeregressor__min_samples_leaf=0.109470939815, decisiontreeregressor__min_samples_split=0.00897202570477
# [CV]  decisiontreeregressor__max_depth=75, decisiontreeregressor__min_samples_leaf=0.0805103573721, decisiontreeregressor__min_samples_split=0.0308407977803, score=0.062834, total=   8.8s
#
# Pickling array (shape=(406922,), dtype=object).
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).
# [CV] decisiontreeregressor__max_depth=83, decisiontreeregressor__min_samples_leaf=0.0328898064328, decisiontreeregressor__min_samples_split=0.00302495999078
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# [CV]  decisiontreeregressor__max_depth=87, decisiontreeregressor__min_samples_leaf=0.0480780910344, decisiontreeregressor__min_samples_split=0.0281787101542, score=0.175032, total=  10.0s
# [CV] decisiontreeregressor__max_depth=86, decisiontreeregressor__min_samples_leaf=0.0613607443263, decisiontreeregressor__min_samples_split=0.0315292922169
# Pickling array (shape=(406922,), dtype=object).[Parallel(n_jobs=-1)]: Done  13 out of 100 | elapsed:   38.3s remaining:  4.3min
#
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# [CV]  decisiontreeregressor__max_depth=86, decisiontreeregressor__min_samples_leaf=0.073184223593, decisiontreeregressor__min_samples_split=0.0665688701074, score=0.094843, total=   9.0s
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# [CV] decisiontreeregressor__max_depth=81, decisiontreeregressor__min_samples_leaf=0.0391591833592, decisiontreeregressor__min_samples_split=0.0382112732021
# Pickling array (shape=(406922,), dtype=object).
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# [CV]  decisiontreeregressor__max_depth=79, decisiontreeregressor__min_samples_leaf=0.0507810916207, decisiontreeregressor__min_samples_split=0.00303966523363, score=0.175032, total=   9.6s
# [Parallel(n_jobs=-1)]: Done  15 out of 100 | elapsed:   41.4s remaining:  3.9min
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# [CV] decisiontreeregressor__max_depth=82, decisiontreeregressor__min_samples_leaf=0.0973425524135, decisiontreeregressor__min_samples_split=0.0139331667524
# Pickling array (shape=(406922,), dtype=object).
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# [CV]  decisiontreeregressor__max_depth=82, decisiontreeregressor__min_samples_leaf=0.060259667285, decisiontreeregressor__min_samples_split=0.00640376164113, score=0.132496, total=   9.6s
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).
# [CV] decisiontreeregressor__max_depth=83, decisiontreeregressor__min_samples_leaf=0.0946219044457, decisiontreeregressor__min_samples_split=0.00562643091831
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# [CV]  decisiontreeregressor__max_depth=86, decisiontreeregressor__min_samples_leaf=0.0678524473481, decisiontreeregressor__min_samples_split=0.00105676181232, score=0.102256, total=  10.4s
# [CV] decisiontreeregressor__max_depth=83, decisiontreeregressor__min_samples_leaf=0.0889180776651, decisiontreeregressor__min_samples_split=0.0435951585239
# [CV]  decisiontreeregressor__max_depth=80, decisiontreeregressor__min_samples_leaf=0.08152939084, decisiontreeregressor__min_samples_split=0.00340779110561, score=0.051648, total=   8.7s
# Pickling array (shape=(406922,), dtype=object).[Parallel(n_jobs=-1)]: Done  17 out of 100 | elapsed:   45.7s remaining:  3.7min
#
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# [CV]  decisiontreeregressor__max_depth=82, decisiontreeregressor__min_samples_leaf=0.109470939815, decisiontreeregressor__min_samples_split=0.00897202570477, score=0.040293, total=   8.4s
# [CV] decisiontreeregressor__max_depth=86, decisiontreeregressor__min_samples_leaf=0.0530991159164, decisiontreeregressor__min_samples_split=0.070690973429
# Pickling array (shape=(406922,), dtype=object).[Parallel(n_jobs=-1)]: Done  19 out of 100 | elapsed:   47.5s remaining:  3.4min
#
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# [CV] decisiontreeregressor__max_depth=82, decisiontreeregressor__min_samples_leaf=0.0314528338059, decisiontreeregressor__min_samples_split=0.0114127682851
# Pickling array (shape=(406922,), dtype=object).
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).
# [CV] decisiontreeregressor__max_depth=85, decisiontreeregressor__min_samples_leaf=0.0552216425475, decisiontreeregressor__min_samples_split=0.0142775792455
# [CV]  decisiontreeregressor__max_depth=86, decisiontreeregressor__min_samples_leaf=0.0613607443263, decisiontreeregressor__min_samples_split=0.0315292922169, score=0.132496, total=   9.3s
# [CV]  decisiontreeregressor__max_depth=83, decisiontreeregressor__min_samples_leaf=0.0328898064328, decisiontreeregressor__min_samples_split=0.00302495999078, score=0.243505, total=  11.1s
# ...
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).[CV]  decisiontreeregressor__max_depth=81, decisiontreeregressor__min_samples_leaf=0.0837063012924, decisiontreeregressor__min_samples_split=0.0958898195387, score=0.052325, total=   8.8s
#
# [Parallel(n_jobs=-1)]: Done  85 out of 100 | elapsed:  2.8min remaining:   29.4s
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).[CV] decisiontreeregressor__max_depth=79, decisiontreeregressor__min_samples_leaf=0.0650746037949, decisiontreeregressor__min_samples_split=0.0162122282684
#
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).
# [CV] decisiontreeregressor__max_depth=84, decisiontreeregressor__min_samples_leaf=0.0876076906864, decisiontreeregressor__min_samples_split=0.0201481910181
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).[CV]  decisiontreeregressor__max_depth=78, decisiontreeregressor__min_samples_leaf=0.0299841104483, decisiontreeregressor__min_samples_split=0.0350235479804, score=0.239606, total=  10.7s
#
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).[CV]  decisiontreeregressor__max_depth=83, decisiontreeregressor__min_samples_leaf=0.0636947546606, decisiontreeregressor__min_samples_split=0.0121259149817, score=0.133559, total=   9.5s
# [CV] decisiontreeregressor__max_depth=87, decisiontreeregressor__min_samples_leaf=0.0188066394533, decisiontreeregressor__min_samples_split=0.0341643903054
#
# [Parallel(n_jobs=-1)]: Done  87 out of 100 | elapsed:  2.8min remaining:   25.5s
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).
# [CV] decisiontreeregressor__max_depth=90, decisiontreeregressor__min_samples_leaf=0.0725478426144, decisiontreeregressor__min_samples_split=0.0235851984886
# [CV]  decisiontreeregressor__max_depth=81, decisiontreeregressor__min_samples_leaf=0.0476516477295, decisiontreeregressor__min_samples_split=0.0299670814356, score=0.166956, total=   9.7s
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# [CV]  decisiontreeregressor__max_depth=87, decisiontreeregressor__min_samples_leaf=0.0558112088984, decisiontreeregressor__min_samples_split=0.00196076985358, score=0.140247, total=   9.4s
# [CV] decisiontreeregressor__max_depth=86, decisiontreeregressor__min_samples_leaf=0.0224914727015, decisiontreeregressor__min_samples_split=0.0146789582547
# Pickling array (shape=(406922,), dtype=object).[Parallel(n_jobs=-1)]: Done  89 out of 100 | elapsed:  2.9min remaining:   21.5s
#
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).[CV] decisiontreeregressor__max_depth=89, decisiontreeregressor__min_samples_leaf=0.0856104795468, decisiontreeregressor__min_samples_split=0.00788785413894
# [CV]  decisiontreeregressor__max_depth=86, decisiontreeregressor__min_samples_leaf=0.0490370746332, decisiontreeregressor__min_samples_split=0.00303048273326, score=0.166956, total=   9.9s
#
# Pickling array (shape=(406922,), dtype=object).
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# [CV]  decisiontreeregressor__max_depth=81, decisiontreeregressor__min_samples_leaf=0.0986336523177, decisiontreeregressor__min_samples_split=0.00237440340926, score=0.040011, total=   8.4s
# [Parallel(n_jobs=-1)]: Done  91 out of 100 | elapsed:  2.9min remaining:   17.5s
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(254,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).[CV] decisiontreeregressor__max_depth=82, decisiontreeregressor__min_samples_leaf=0.0461031906837, decisiontreeregressor__min_samples_split=0.0384255526367
#
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(19, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-7bbbe223bab168b8bb13d66f9c531fb8.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(19,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(19,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# [CV]  decisiontreeregressor__max_depth=82, decisiontreeregressor__min_samples_leaf=0.0705266409054, decisiontreeregressor__min_samples_split=0.0546194250579, score=0.125312, total=   9.0s
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52444_140214301504848/52444-140214389388432-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# [CV] decisiontreeregressor__max_depth=87, decisiontreeregressor__min_samples_leaf=0.0502118475317, decisiontreeregressor__min_samples_split=0.0226437412743
# [CV]  decisiontreeregressor__max_depth=79, decisiontreeregressor__min_samples_leaf=0.0650746037949, decisiontreeregressor__min_samples_split=0.0162122282684, score=0.133575, total=   9.4s
# [Parallel(n_jobs=-1)]: Done  93 out of 100 | elapsed:  3.0min remaining:   13.6s
# [CV]  decisiontreeregressor__max_depth=84, decisiontreeregressor__min_samples_leaf=0.0876076906864, decisiontreeregressor__min_samples_split=0.0201481910181, score=0.052185, total=   8.6s
# [CV]  decisiontreeregressor__max_depth=90, decisiontreeregressor__min_samples_leaf=0.0725478426144, decisiontreeregressor__min_samples_split=0.0235851984886, score=0.125312, total=   9.0s
# [Parallel(n_jobs=-1)]: Done  95 out of 100 | elapsed:  3.1min remaining:    9.8s
# [CV]  decisiontreeregressor__max_depth=87, decisiontreeregressor__min_samples_leaf=0.0188066394533, decisiontreeregressor__min_samples_split=0.0341643903054, score=0.298874, total=  12.7s
# [CV]  decisiontreeregressor__max_depth=89, decisiontreeregressor__min_samples_leaf=0.0856104795468, decisiontreeregressor__min_samples_split=0.00788785413894, score=0.052325, total=   8.7s
# [Parallel(n_jobs=-1)]: Done  97 out of 100 | elapsed:  3.1min remaining:    5.8s
# [CV]  decisiontreeregressor__max_depth=86, decisiontreeregressor__min_samples_leaf=0.0224914727015, decisiontreeregressor__min_samples_split=0.0146789582547, score=0.289742, total=  11.8s
# [CV]  decisiontreeregressor__max_depth=82, decisiontreeregressor__min_samples_leaf=0.0461031906837, decisiontreeregressor__min_samples_split=0.0384255526367, score=0.166960, total=   9.5s
# [CV]  decisiontreeregressor__max_depth=87, decisiontreeregressor__min_samples_leaf=0.0502118475317, decisiontreeregressor__min_samples_split=0.0226437412743, score=0.166906, total=   9.4s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  3.2min finished

# %%
results = pd.DataFrame(model2.cv_results_)
results[results.mean_test_score > 0.3].T
# Out:
#                                                                                                 8
# mean_fit_time                                                                             10.8678
# mean_score_time                                                                           1.05293
# mean_test_score                                                                          0.313319
# mean_train_score                                                                         0.314407
# param_decisiontreeregressor__max_depth                                                         85
# param_decisiontreeregressor__min_samples_leaf                                            0.016263
# param_decisiontreeregressor__min_samples_split                                         0.00741915
# params                                          {u'decisiontreeregressor__max_depth': 85, u'de...
# rank_test_score                                                                                 1
# split0_test_score                                                                        0.313319
# split0_train_score                                                                       0.314407
# std_fit_time                                                                                    0
# std_score_time                                                                                  0
# std_test_score                                                                                  0
# std_train_score                                                                                 0

# %%
results = pd.DataFrame(model.cv_results_).T
results
# Out:
#                                                                                                 0  \
# mean_fit_time                                                                             8.68406
# mean_score_time                                                                           1.05191
# mean_test_score                                                                          0.170211
# mean_train_score                                                                         0.170712
# param_decisiontreeregressor__max_depth                                                         50
# param_decisiontreeregressor__min_samples_leaf                                                0.05
# param_decisiontreeregressor__min_samples_split                                               0.05
# params                                          {u'decisiontreeregressor__max_depth': 50, u'de...
# rank_test_score                                                                                 2
# split0_test_score                                                                        0.170211
# split0_train_score                                                                       0.170712
# std_fit_time                                                                                    0
# std_score_time                                                                                  0
# std_test_score                                                                                  0
# std_train_score                                                                                 0
#
#                                                                                                 1  \
# mean_fit_time                                                                             8.76414
# mean_score_time                                                                           1.04649
# mean_test_score                                                                          0.170211
# mean_train_score                                                                         0.170712
# param_decisiontreeregressor__max_depth                                                         50
# param_decisiontreeregressor__min_samples_leaf                                                0.05
# param_decisiontreeregressor__min_samples_split                                                0.1
# params                                          {u'decisiontreeregressor__max_depth': 50, u'de...
# rank_test_score                                                                                 2
# split0_test_score                                                                        0.170211
# split0_train_score                                                                       0.170712
# std_fit_time                                                                                    0
# std_score_time                                                                                  0
# std_test_score                                                                                  0
# std_train_score                                                                                 0
#
#                                                                                                 2  \
# mean_fit_time                                                                             12.1061
# mean_score_time                                                                           1.04655
# mean_test_score                                                                          0.354086
# mean_train_score                                                                         0.354199
# param_decisiontreeregressor__max_depth                                                         75
# param_decisiontreeregressor__min_samples_leaf                                                0.01
# param_decisiontreeregressor__min_samples_split                                               0.05
# params                                          {u'decisiontreeregressor__max_depth': 75, u'de...
# rank_test_score                                                                                 1
# split0_test_score                                                                        0.354086
# split0_train_score                                                                       0.354199
# std_fit_time                                                                                    0
# std_score_time                                                                                  0
# std_test_score                                                                                  0
# std_train_score                                                                                 0
#
#                                                                                                 3  \
# mean_fit_time                                                                             8.32671
# mean_score_time                                                                           1.03941
# mean_test_score                                                                          0.170068
# mean_train_score                                                                         0.170543
# param_decisiontreeregressor__max_depth                                                         10
# param_decisiontreeregressor__min_samples_leaf                                                0.05
# param_decisiontreeregressor__min_samples_split                                               0.05
# params                                          {u'decisiontreeregressor__max_depth': 10, u'de...
# rank_test_score                                                                                 4
# split0_test_score                                                                        0.170068
# split0_train_score                                                                       0.170543
# std_fit_time                                                                                    0
# std_score_time                                                                                  0
# std_test_score                                                                                  0
# std_train_score                                                                                 0
#
#                                                                                                 4
# mean_fit_time                                                                             7.00678
# mean_score_time                                                                           1.01848
# mean_test_score                                                                         0.0663755
# mean_train_score                                                                        0.0656133
# param_decisiontreeregressor__max_depth                                                         10
# param_decisiontreeregressor__min_samples_leaf                                                 0.1
# param_decisiontreeregressor__min_samples_split                                               0.05
# params                                          {u'decisiontreeregressor__max_depth': 10, u'de...
# rank_test_score                                                                                 5
# split0_test_score                                                                       0.0663755
# split0_train_score                                                                      0.0656133
# std_fit_time                                                                                    0
# std_score_time                                                                                  0
# std_test_score                                                                                  0
# std_train_score                                                                                 0

# %%
model.best_params_
# Out:
# {'decisiontreeregressor__max_depth': 75,
#  'decisiontreeregressor__min_samples_leaf': 0.01,
#  'decisiontreeregressor__min_samples_split': 0.05}

# %%
model.best_score_
# Out:
# 0.35408592034503239

# %%
model.score(X_test, y_test)
# Out:
# 0.35378645355806615

# %% [markdown]
# ## Conclusion
#
# After much trial and error, the best pre-pruned decision tree I could come up with has an $R^2$ score of 0.35, much less than with Linear Regression.
#
# I'm not in an overfit situation, looking at the CV_train and CV_test $R^2$s. When the tree is bigger, its $R^2$ gets lower, for both CV_train and CV_test sets. I'm not exactly sure why at the moment. I suspect it has to do with the tree-building stopping rule (node purity) being different from minimizing RSS. Or minimizing RSS somehow increases $R^2$. I'll need to read up more on this.
