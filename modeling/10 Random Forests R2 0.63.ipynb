# %% [markdown]
# ## Objective
#
# Use L2 Lasso regularization, see:
# - if $R^2$ improves from 0.56
# - whether we avoid crazy `y_pred`s (presumably from overfitting)
# - which coefficients drop to 0

# %%
from __future__ import division
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline

rcParams['figure.figsize'] = 20, 5
warnings.filterwarnings("ignore", category=DeprecationWarning)
sns.set_style("whitegrid")
sns.set_context("poster")

from helper_functions import dummify_cols_and_baselines, make_alphas, remove_outliers_by_type

# %%
df_orig = pd.read_pickle('../data/data_from_remove_from_dataset.pkl')
df_orig.shape
# Out:
# (516406, 40)

# %% [markdown]
# ## Removing outliers
#
# A standard procedure is to remove values further than 3 standard deviations from the mean. Since I have so many low values and some very high values, I anecdotally think that the low values are very likely to be true, and the high values not so much.
#
# So, I will remove values further than 3 SDs from the median, by type.
#
# Ideally, I would take into account the time dimension. I would like to do so given more time.

# %%
df_outliers_removed = remove_outliers_by_type(df_orig, y_col='COMPLETION_HOURS_LOG_10')
df_outliers_removed.shape
# Out:
# helper_functions.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   group[pd.np.abs(group - group.median()) > stds * group.std()] = pd.np.nan
# /home/ec2-user/anaconda2/lib/python2.7/site-packages/pandas/core/frame.py:2454: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._where(-key, value, inplace=True)
# (508653, 40)

# %% [markdown]
# I'm removing ~1.5% of my rows.

# %% [markdown]
# ## Removing columns

# %%
cols_orig_dataset = ['COMPLETION_HOURS_LOG_10', 'TYPE', 'SubmittedPhoto', 'Property_Type', 'Source', 'neighborhood_from_zip']
cols_census = ['race_white',
     'race_black',
     'race_asian',
     'race_hispanic',
     'race_other',
     'poverty_pop_below_poverty_level',
     'earned_income_per_capita',
     'poverty_pop_w_public_assistance',
     'poverty_pop_w_food_stamps',
     'poverty_pop_w_ssi',
     'school',
     'school_std_dev',
     'housing',
     'housing_std_dev',
     'bedroom',
     'bedroom_std_dev',
     'value',
     'value_std_dev',
     'rent',
     'rent_std_dev',
     'income',
     'income_std_dev']
cols_engineered = ['queue_wk', 'queue_wk_open', 'is_description']

# %%
df = df_outliers_removed[cols_orig_dataset + cols_census + cols_engineered]

# %% [markdown]
# ## Dummify

# %%
cols_to_dummify = df.dtypes[df.dtypes == object].index
cols_to_dummify
# Out:
# Index([u'TYPE', u'Property_Type', u'Source', u'neighborhood_from_zip',
#        u'school', u'housing'],
#       dtype='object')

# %%
df_dummified, baseline_cols = dummify_cols_and_baselines(df, cols_to_dummify)
# Out:
# Zoning is baseline 0 6
# other is baseline 1 6
# Twitter is baseline 2 6
# West Roxbury is baseline 3 6
# 8_6th_grade is baseline 4 6
# rent is baseline 5 6

# %%
df_dummified.shape
# Out:
# (508653, 253)

# %% [markdown]
# ## Running model

# %%
from sklearn.cross_validation import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.cross_validation import ShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
# Out:
# /home/ec2-user/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df_dummified.drop('COMPLETION_HOURS_LOG_10', axis=1), 
    df_dummified.COMPLETION_HOURS_LOG_10, 
    test_size=0.2, 
    random_state=300
)

# %%
pipe = make_pipeline(StandardScaler(), RandomForestRegressor(verbose=100))

# %%
cv = ShuffleSplit(X_train.shape[0], n_iter=1, test_size=0.2, random_state=300)

# %%
# I wanted to use oob_score but need for loop
# http://scikit-learn.org/stable/auto_examples/ensemble/plot_ensemble_oob.html
# decided that with mulitple folds, each fold had similar performance, so went with k=1

params = {'randomforestregressor__max_depth': [23, 27], 
          'randomforestregressor__n_estimators': [30], # test error starts to asymptote around 30 trees
          'randomforestregressor__oob_score': [True]}
model4 = GridSearchCV(pipe, param_grid=params, n_jobs=-1, cv=cv, verbose=100)
model4.fit(X_train, y_train);
# Out:
# Fitting 1 folds for each of 2 candidates, totalling 2 fits
# Pickling array (shape=(252,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(17, 406922), dtype=float64) to new file /dev/shm/joblib_memmaping_pool_52271_140629515291344/52271-140629504327568-dabc3510d280c7a30d62606c36f527e3.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to new file /dev/shm/joblib_memmaping_pool_52271_140629515291344/52271-140629504327568-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to new file /dev/shm/joblib_memmaping_pool_52271_140629515291344/52271-140629504327568-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(17,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to new file /dev/shm/joblib_memmaping_pool_52271_140629515291344/52271-140629504327568-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to new file /dev/shm/joblib_memmaping_pool_52271_140629515291344/52271-140629504327568-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# Pickling array (shape=(252,), dtype=object).
# Pickling array (shape=(406922,), dtype=object).
# [CV] randomforestregressor__max_depth=23, randomforestregressor__n_estimators=30, randomforestregressor__oob_score=True
# Pickling array (shape=(2, 406922), dtype=bool).
# Memmaping (shape=(17, 406922), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52271_140629515291344/52271-140629504327568-dabc3510d280c7a30d62606c36f527e3.pkl
# Memmaping (shape=(5, 406922), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52271_140629515291344/52271-140629504327568-389b7c8adcba4caca8208567368f53bd.pkl
# Memmaping (shape=(228, 406922), dtype=uint8) to old file /dev/shm/joblib_memmaping_pool_52271_140629515291344/52271-140629504327568-0dd6e0cfba23dae21160906f37814f3c.pkl
# Pickling array (shape=(2,), dtype=object).
# Pickling array (shape=(17,), dtype=object).
# Pickling array (shape=(5,), dtype=object).
# Pickling array (shape=(228,), dtype=object).
# Pickling array (shape=(17,), dtype=int64).
# Pickling array (shape=(5,), dtype=int64).
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(406922,), dtype=float64) to old file /dev/shm/joblib_memmaping_pool_52271_140629515291344/52271-140629504327568-a4af92d7b27e92d6205638ded29d1c26.pkl
# Pickling array (shape=(406922,), dtype=object).
# Memmaping (shape=(325537,), dtype=int64) to old file /dev/shm/joblib_memmaping_pool_52271_140629515291344/52271-140629504327568-d50df740adb08dd8a33a7a6e4d56240b.pkl
# Pickling array (shape=(81385,), dtype=int64).
# [CV] randomforestregressor__max_depth=27, randomforestregressor__n_estimators=30, randomforestregressor__oob_score=True
# building tree 1 of 30
# building tree 1 of 30
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    8.9s remaining:    0.0s
# building tree 2 of 30
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.1s remaining:    0.0s
# building tree 2 of 30
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   18.1s remaining:    0.0s
# building tree 3 of 30
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   20.6s remaining:    0.0s
# building tree 3 of 30
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   27.0s remaining:    0.0s
# building tree 4 of 30
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   30.8s remaining:    0.0s
# building tree 4 of 30
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   36.1s remaining:    0.0s
# building tree 5 of 30
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   41.3s remaining:    0.0s
# building tree 5 of 30
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   45.3s remaining:    0.0s
# building tree 6 of 30
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   51.8s remaining:    0.0s
# building tree 6 of 30
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   54.3s remaining:    0.0s
# building tree 7 of 30
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  1.1min remaining:    0.0s
# building tree 8 of 30
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  1.0min remaining:    0.0s
# building tree 7 of 30
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  1.2min remaining:    0.0s
# building tree 9 of 30
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  1.2min remaining:    0.0s
# building tree 8 of 30
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  1.4min remaining:    0.0s
# building tree 10 of 30
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  1.4min remaining:    0.0s
# building tree 9 of 30
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  1.5min remaining:    0.0s
# building tree 11 of 30
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  1.5min remaining:    0.0s
# building tree 10 of 30
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:  1.6min remaining:    0.0s
# building tree 12 of 30
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  1.7min remaining:    0.0s
# building tree 11 of 30
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:  1.8min remaining:    0.0s
# building tree 13 of 30
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:  1.9min remaining:    0.0s
# building tree 12 of 30
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:  1.9min remaining:    0.0s
# building tree 14 of 30
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:  2.1min remaining:    0.0s
# building tree 13 of 30
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:  2.1min remaining:    0.0s
# building tree 15 of 30
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:  2.3min remaining:    0.0s
# building tree 16 of 30
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:  2.2min remaining:    0.0s
# building tree 14 of 30
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:  2.4min remaining:    0.0s
# building tree 17 of 30
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:  2.4min remaining:    0.0s
# building tree 15 of 30
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:  2.5min remaining:    0.0s
# building tree 18 of 30
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:  2.6min remaining:    0.0s
# building tree 16 of 30
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:  2.7min remaining:    0.0s
# building tree 19 of 30
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:  2.8min remaining:    0.0s
# building tree 17 of 30
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:  2.8min remaining:    0.0s
# building tree 20 of 30
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:  2.9min remaining:    0.0s
# building tree 18 of 30
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:  3.0min remaining:    0.0s
# building tree 21 of 30
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:  3.1min remaining:    0.0s
# building tree 19 of 30
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:  3.1min remaining:    0.0s
# building tree 22 of 30
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:  3.3min remaining:    0.0s
# building tree 20 of 30
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:  3.3min remaining:    0.0s
# building tree 23 of 30
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:  3.4min remaining:    0.0s
# building tree 24 of 30
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:  3.4min remaining:    0.0s
# building tree 21 of 30
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:  3.6min remaining:    0.0s
# building tree 25 of 30
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:  3.6min remaining:    0.0s
# building tree 22 of 30
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:  3.7min remaining:    0.0s
# building tree 26 of 30
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:  3.8min remaining:    0.0s
# building tree 23 of 30
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:  3.9min remaining:    0.0s
# building tree 27 of 30
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:  3.9min remaining:    0.0s
# building tree 24 of 30
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:  4.0min remaining:    0.0s
# building tree 28 of 30
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:  4.1min remaining:    0.0s
# building tree 25 of 30
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:  4.2min remaining:    0.0s
# building tree 29 of 30
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:  4.3min remaining:    0.0s
# building tree 26 of 30
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:  4.3min remaining:    0.0s
# building tree 30 of 30
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:  4.5min remaining:    0.0s
# building tree 27 of 30
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  4.5min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  4.5min finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    0.6s finished
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:  4.6min remaining:    0.0s
# building tree 28 of 30
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    1.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    2.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    2.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    2.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:    2.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    2.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    2.9s finished
# [CV]  randomforestregressor__max_depth=23, randomforestregressor__n_estimators=30, randomforestregressor__oob_score=True, score=0.591233, total= 4.8min
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:  4.8min remaining:    0.0s
# building tree 29 of 30
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:  5.0min remaining:    0.0s
# building tree 30 of 30
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  5.1min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  5.1min finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    2.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    2.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    3.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    3.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    3.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    3.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    3.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    3.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:    3.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    4.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    4.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    4.2s finished
# [CV]  randomforestregressor__max_depth=27, randomforestregressor__n_estimators=30, randomforestregressor__oob_score=True, score=0.608877, total= 5.4min
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:  5.7min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:  5.7min finished
# building tree 1 of 30
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   13.2s remaining:    0.0s
# building tree 2 of 30
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   26.3s remaining:    0.0s
# building tree 3 of 30
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   39.4s remaining:    0.0s
# building tree 4 of 30
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:   52.4s remaining:    0.0s
# building tree 5 of 30
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  1.1min remaining:    0.0s
# building tree 6 of 30
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  1.3min remaining:    0.0s
# building tree 7 of 30
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  1.5min remaining:    0.0s
# building tree 8 of 30
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:  1.7min remaining:    0.0s
# building tree 9 of 30
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:  1.9min remaining:    0.0s
# building tree 10 of 30
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  2.1min remaining:    0.0s
# building tree 11 of 30
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:  2.4min remaining:    0.0s
# building tree 12 of 30
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:  2.6min remaining:    0.0s
# building tree 13 of 30
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:  2.8min remaining:    0.0s
# building tree 14 of 30
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:  3.0min remaining:    0.0s
# building tree 15 of 30
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:  3.2min remaining:    0.0s
# building tree 16 of 30
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:  3.4min remaining:    0.0s
# building tree 17 of 30
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:  3.6min remaining:    0.0s
# building tree 18 of 30
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:  3.9min remaining:    0.0s
# building tree 19 of 30
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:  4.1min remaining:    0.0s
# building tree 20 of 30
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:  4.4min remaining:    0.0s
# building tree 21 of 30
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:  4.6min remaining:    0.0s
# building tree 22 of 30
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:  4.9min remaining:    0.0s
# building tree 23 of 30
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:  5.1min remaining:    0.0s
# building tree 24 of 30
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:  5.3min remaining:    0.0s
# building tree 25 of 30
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:  5.5min remaining:    0.0s
# building tree 26 of 30
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:  5.8min remaining:    0.0s
# building tree 27 of 30
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:  6.0min remaining:    0.0s
# building tree 28 of 30
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:  6.2min remaining:    0.0s
# building tree 29 of 30
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:  6.5min remaining:    0.0s
# building tree 30 of 30
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  6.7min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  6.7min finished

# %%
# I wanted to use oob_score but need for loop
# http://scikit-learn.org/stable/auto_examples/ensemble/plot_ensemble_oob.html
# decided that with mulitple folds, each fold had similar performance, so went with k=1

params = {'randomforestregressor__max_depth': [50], 
          'randomforestregressor__n_estimators': [30], # test error starts to asymptote around 30 trees}
model = GridSearchCV(pipe, param_grid=params, n_jobs=-1, cv=cv, verbose=100)
model.fit(X_train, y_train);

# %%
results = pd.DataFrame(model4.cv_results_).T
results
# Out:
#                                                                                            0  \
# mean_fit_time                                                                         285.89
# mean_score_time                                                                      1.78831
# mean_test_score                                                                     0.591233
# mean_train_score                                                                     0.69527
# param_randomforestregressor__max_depth                                                    23
# param_randomforestregressor__n_estimators                                                 30
# param_randomforestregressor__oob_score                                                  True
# params                                     {u'randomforestregressor__max_depth': 23, u'ra...
# rank_test_score                                                                            2
# split0_test_score                                                                   0.591233
# split0_train_score                                                                   0.69527
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0
#
#                                                                                            1
# mean_fit_time                                                                        324.842
# mean_score_time                                                                      2.07434
# mean_test_score                                                                     0.608877
# mean_train_score                                                                     0.75361
# param_randomforestregressor__max_depth                                                    27
# param_randomforestregressor__n_estimators                                                 30
# param_randomforestregressor__oob_score                                                  True
# params                                     {u'randomforestregressor__max_depth': 27, u'ra...
# rank_test_score                                                                            1
# split0_test_score                                                                   0.608877
# split0_train_score                                                                   0.75361
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0

# %%
results = pd.DataFrame(model3.cv_results_).T
results
# Out:
#                                                                                            0  \
# mean_fit_time                                                                        460.889
# mean_score_time                                                                      2.81586
# mean_test_score                                                                     0.628366
# mean_train_score                                                                    0.916543
# param_randomforestregressor__max_depth                                                    50
# param_randomforestregressor__n_estimators                                                 30
# param_randomforestregressor__oob_score                                                  True
# params                                     {u'randomforestregressor__max_depth': 50, u'ra...
# rank_test_score                                                                            1
# split0_test_score                                                                   0.628366
# split0_train_score                                                                  0.916543
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0
#
#                                                                                            1  \
# mean_fit_time                                                                        490.748
# mean_score_time                                                                      3.07321
# mean_test_score                                                                     0.624944
# mean_train_score                                                                    0.940756
# param_randomforestregressor__max_depth                                                    75
# param_randomforestregressor__n_estimators                                                 30
# param_randomforestregressor__oob_score                                                  True
# params                                     {u'randomforestregressor__max_depth': 75, u'ra...
# rank_test_score                                                                            2
# split0_test_score                                                                   0.624944
# split0_train_score                                                                  0.940756
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0
#
#                                                                                            2
# mean_fit_time                                                                        488.439
# mean_score_time                                                                      3.01894
# mean_test_score                                                                     0.624703
# mean_train_score                                                                     0.94142
# param_randomforestregressor__max_depth                                                    85
# param_randomforestregressor__n_estimators                                                 30
# param_randomforestregressor__oob_score                                                  True
# params                                     {u'randomforestregressor__max_depth': 85, u'ra...
# rank_test_score                                                                            3
# split0_test_score                                                                   0.624703
# split0_train_score                                                                   0.94142
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0

# %%
results = pd.DataFrame(model2.cv_results_).T
results
# Out:
#                                                                                            0  \
# mean_fit_time                                                                         59.176
# mean_score_time                                                                      1.28531
# mean_test_score                                                                      0.46555
# mean_train_score                                                                    0.473085
# param_randomforestregressor__max_depth                                                    10
# param_randomforestregressor__n_estimators                                                 10
# param_randomforestregressor__oob_score                                                  True
# params                                     {u'randomforestregressor__max_depth': 10, u'ra...
# rank_test_score                                                                            1
# split0_test_score                                                                    0.46555
# split0_train_score                                                                  0.473085
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                   5.55112e-17
# std_train_score                                                                            0
#
#                                                                                            1  \
# mean_fit_time                                                                         135.95
# mean_score_time                                                                      1.34715
# mean_test_score                                                                     0.464261
# mean_train_score                                                                    0.471913
# param_randomforestregressor__max_depth                                                    10
# param_randomforestregressor__n_estimators                                                 25
# param_randomforestregressor__oob_score                                                  True
# params                                     {u'randomforestregressor__max_depth': 10, u'ra...
# rank_test_score                                                                            2
# split0_test_score                                                                   0.464261
# split0_train_score                                                                  0.471913
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0
#
#                                                                                            2
# mean_fit_time                                                                        210.871
# mean_score_time                                                                       1.4439
# mean_test_score                                                                     0.464148
# mean_train_score                                                                     0.47176
# param_randomforestregressor__max_depth                                                    10
# param_randomforestregressor__n_estimators                                                 40
# param_randomforestregressor__oob_score                                                  True
# params                                     {u'randomforestregressor__max_depth': 10, u'ra...
# rank_test_score                                                                            3
# split0_test_score                                                                   0.464148
# split0_train_score                                                                   0.47176
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                   5.55112e-17
# std_train_score                                                                            0

# %%
results = pd.DataFrame(model.cv_results_).T
results
# Out:
#                                                                                            0  \
# mean_fit_time                                                                        279.679
# mean_score_time                                                                      1.55904
# mean_test_score                                                                      0.46469
# mean_train_score                                                                    0.472256
# param_randomforestregressor__max_depth                                                    10
# param_randomforestregressor__n_estimators                                                 50
# params                                     {u'randomforestregressor__max_depth': 10, u'ra...
# rank_test_score                                                                            9
# split0_test_score                                                                    0.46469
# split0_train_score                                                                  0.472256
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                   5.55112e-17
# std_train_score                                                                            0
#
#                                                                                            1  \
# mean_fit_time                                                                        538.562
# mean_score_time                                                                      1.91368
# mean_test_score                                                                     0.464717
# mean_train_score                                                                    0.472292
# param_randomforestregressor__max_depth                                                    10
# param_randomforestregressor__n_estimators                                                100
# params                                     {u'randomforestregressor__max_depth': 10, u'ra...
# rank_test_score                                                                            8
# split0_test_score                                                                   0.464717
# split0_train_score                                                                  0.472292
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0
#
#                                                                                            2  \
# mean_fit_time                                                                        781.369
# mean_score_time                                                                      2.45124
# mean_test_score                                                                      0.46495
# mean_train_score                                                                    0.472518
# param_randomforestregressor__max_depth                                                    10
# param_randomforestregressor__n_estimators                                                150
# params                                     {u'randomforestregressor__max_depth': 10, u'ra...
# rank_test_score                                                                            7
# split0_test_score                                                                    0.46495
# split0_train_score                                                                  0.472518
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                   5.55112e-17
# std_train_score                                                                            0
#
#                                                                                            3  \
# mean_fit_time                                                                        877.744
# mean_score_time                                                                      4.53693
# mean_test_score                                                                      0.63119
# mean_train_score                                                                    0.944207
# param_randomforestregressor__max_depth                                                   100
# param_randomforestregressor__n_estimators                                                 50
# params                                     {u'randomforestregressor__max_depth': 100, u'r...
# rank_test_score                                                                            5
# split0_test_score                                                                    0.63119
# split0_train_score                                                                  0.944207
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0
#
#                                                                                            4  \
# mean_fit_time                                                                        1679.15
# mean_score_time                                                                      7.57992
# mean_test_score                                                                      0.63385
# mean_train_score                                                                    0.946224
# param_randomforestregressor__max_depth                                                   100
# param_randomforestregressor__n_estimators                                                100
# params                                     {u'randomforestregressor__max_depth': 100, u'r...
# rank_test_score                                                                            3
# split0_test_score                                                                    0.63385
# split0_train_score                                                                  0.946224
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0
#
#                                                                                            5  \
# mean_fit_time                                                                        2430.63
# mean_score_time                                                                      10.2313
# mean_test_score                                                                     0.634941
# mean_train_score                                                                    0.946885
# param_randomforestregressor__max_depth                                                   100
# param_randomforestregressor__n_estimators                                                150
# params                                     {u'randomforestregressor__max_depth': 100, u'r...
# rank_test_score                                                                            1
# split0_test_score                                                                   0.634941
# split0_train_score                                                                  0.946885
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0
#
#                                                                                            6  \
# mean_fit_time                                                                        844.865
# mean_score_time                                                                      4.53368
# mean_test_score                                                                     0.631045
# mean_train_score                                                                    0.944177
# param_randomforestregressor__max_depth                                                  None
# param_randomforestregressor__n_estimators                                                 50
# params                                     {u'randomforestregressor__max_depth': None, u'...
# rank_test_score                                                                            6
# split0_test_score                                                                   0.631045
# split0_train_score                                                                  0.944177
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0
#
#                                                                                            7  \
# mean_fit_time                                                                        1641.91
# mean_score_time                                                                      7.26755
# mean_test_score                                                                     0.633741
# mean_train_score                                                                    0.946196
# param_randomforestregressor__max_depth                                                  None
# param_randomforestregressor__n_estimators                                                100
# params                                     {u'randomforestregressor__max_depth': None, u'...
# rank_test_score                                                                            4
# split0_test_score                                                                   0.633741
# split0_train_score                                                                  0.946196
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0
#
#                                                                                            8
# mean_fit_time                                                                           2462
# mean_score_time                                                                      10.0672
# mean_test_score                                                                     0.634933
# mean_train_score                                                                    0.946873
# param_randomforestregressor__max_depth                                                  None
# param_randomforestregressor__n_estimators                                                150
# params                                     {u'randomforestregressor__max_depth': None, u'...
# rank_test_score                                                                            2
# split0_test_score                                                                   0.634933
# split0_train_score                                                                  0.946873
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0

# %% [markdown]
# ## Conclusion
#
# Random Forests, unsurprisingly, beats Decision Tree + pruning and Linear Regression with L2 Lasso regularization. The best performing model, with $R^2=0.64$, had 150 trees and a depth of 100.
#
# The $R^2$ starts to asymptote around 50 trees and 30 depth. I will use this as my best model to make predictions.

# %%
model3.best_score_
# Out:
# 0.62836648105953374

# %%
model.best_score_
# Out:
# 0.63494073187298072

# %%
model.score(X_test, y_test)
# Out:
# 0.64116203270827277

# %%
y_pred = model.predict(X_test)

# %%
pd.Series(y_pred).describe()
# Out:
# count    101731.000000
# mean          1.710346
# std           0.938206
# min          -2.820321
# 25%           1.145173
# 50%           1.905054
# 75%           2.334531
# max           4.325803
# dtype: float64

# %%
y_test.describe()
# Out:
# count    101731.000000
# mean          1.717758
# std           1.119753
# min          -2.857332
# 25%           1.353593
# 50%           1.865962
# 75%           2.375708
# max           4.582340
# Name: COMPLETION_HOURS_LOG_10, dtype: float64

# %%
mean_squared_error(y_test, y_pred)**0.5
# Out:
# 0.67076351996732153

# %%
y_pred3 = model3.predict(X_test)
# Out:
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    1.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:    1.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:    1.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    1.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:    2.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    2.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:    2.1s finished

# %%
mean_squared_error(y_test, y_pred3)**0.5
# Out:
# 0.67614465610813312

# %%
model3.best_estimator_.steps[-1][-1].oob_score_
# Out:
# 0.6177917198912124

# %%
model3.best_params_
# Out:
# {'randomforestregressor__max_depth': 50,
#  'randomforestregressor__n_estimators': 30,
#  'randomforestregressor__oob_score': True}

# %%
model.best_params_
# Out:
# {'randomforestregressor__max_depth': 100,
#  'randomforestregressor__n_estimators': 150}

# %%
results = pd.DataFrame(model.cv_results_).T
results
# Out:
#                                                                                            0  \
# mean_fit_time                                                                        279.679
# mean_score_time                                                                      1.55904
# mean_test_score                                                                      0.46469
# mean_train_score                                                                    0.472256
# param_randomforestregressor__max_depth                                                    10
# param_randomforestregressor__n_estimators                                                 50
# params                                     {u'randomforestregressor__max_depth': 10, u'ra...
# rank_test_score                                                                            9
# split0_test_score                                                                    0.46469
# split0_train_score                                                                  0.472256
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                   5.55112e-17
# std_train_score                                                                            0
#
#                                                                                            1  \
# mean_fit_time                                                                        538.562
# mean_score_time                                                                      1.91368
# mean_test_score                                                                     0.464717
# mean_train_score                                                                    0.472292
# param_randomforestregressor__max_depth                                                    10
# param_randomforestregressor__n_estimators                                                100
# params                                     {u'randomforestregressor__max_depth': 10, u'ra...
# rank_test_score                                                                            8
# split0_test_score                                                                   0.464717
# split0_train_score                                                                  0.472292
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0
#
#                                                                                            2  \
# mean_fit_time                                                                        781.369
# mean_score_time                                                                      2.45124
# mean_test_score                                                                      0.46495
# mean_train_score                                                                    0.472518
# param_randomforestregressor__max_depth                                                    10
# param_randomforestregressor__n_estimators                                                150
# params                                     {u'randomforestregressor__max_depth': 10, u'ra...
# rank_test_score                                                                            7
# split0_test_score                                                                    0.46495
# split0_train_score                                                                  0.472518
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                   5.55112e-17
# std_train_score                                                                            0
#
#                                                                                            3  \
# mean_fit_time                                                                        877.744
# mean_score_time                                                                      4.53693
# mean_test_score                                                                      0.63119
# mean_train_score                                                                    0.944207
# param_randomforestregressor__max_depth                                                   100
# param_randomforestregressor__n_estimators                                                 50
# params                                     {u'randomforestregressor__max_depth': 100, u'r...
# rank_test_score                                                                            5
# split0_test_score                                                                    0.63119
# split0_train_score                                                                  0.944207
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0
#
#                                                                                            4  \
# mean_fit_time                                                                        1679.15
# mean_score_time                                                                      7.57992
# mean_test_score                                                                      0.63385
# mean_train_score                                                                    0.946224
# param_randomforestregressor__max_depth                                                   100
# param_randomforestregressor__n_estimators                                                100
# params                                     {u'randomforestregressor__max_depth': 100, u'r...
# rank_test_score                                                                            3
# split0_test_score                                                                    0.63385
# split0_train_score                                                                  0.946224
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0
#
#                                                                                            5  \
# mean_fit_time                                                                        2430.63
# mean_score_time                                                                      10.2313
# mean_test_score                                                                     0.634941
# mean_train_score                                                                    0.946885
# param_randomforestregressor__max_depth                                                   100
# param_randomforestregressor__n_estimators                                                150
# params                                     {u'randomforestregressor__max_depth': 100, u'r...
# rank_test_score                                                                            1
# split0_test_score                                                                   0.634941
# split0_train_score                                                                  0.946885
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0
#
#                                                                                            6  \
# mean_fit_time                                                                        844.865
# mean_score_time                                                                      4.53368
# mean_test_score                                                                     0.631045
# mean_train_score                                                                    0.944177
# param_randomforestregressor__max_depth                                                  None
# param_randomforestregressor__n_estimators                                                 50
# params                                     {u'randomforestregressor__max_depth': None, u'...
# rank_test_score                                                                            6
# split0_test_score                                                                   0.631045
# split0_train_score                                                                  0.944177
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0
#
#                                                                                            7  \
# mean_fit_time                                                                        1641.91
# mean_score_time                                                                      7.26755
# mean_test_score                                                                     0.633741
# mean_train_score                                                                    0.946196
# param_randomforestregressor__max_depth                                                  None
# param_randomforestregressor__n_estimators                                                100
# params                                     {u'randomforestregressor__max_depth': None, u'...
# rank_test_score                                                                            4
# split0_test_score                                                                   0.633741
# split0_train_score                                                                  0.946196
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0
#
#                                                                                            8
# mean_fit_time                                                                           2462
# mean_score_time                                                                      10.0672
# mean_test_score                                                                     0.634933
# mean_train_score                                                                    0.946873
# param_randomforestregressor__max_depth                                                  None
# param_randomforestregressor__n_estimators                                                150
# params                                     {u'randomforestregressor__max_depth': None, u'...
# rank_test_score                                                                            2
# split0_test_score                                                                   0.634933
# split0_train_score                                                                  0.946873
# std_fit_time                                                                               0
# std_score_time                                                                             0
# std_test_score                                                                             0
# std_train_score                                                                            0

# %%
results.T[['param_randomforestregressor__max_depth', 'param_randomforestregressor__n_estimators', 'mean_test_score']]
# Out:
#   param_randomforestregressor__max_depth  \
# 0                                     10
# 1                                     10
# 2                                     10
# 3                                    100
# 4                                    100
# 5                                    100
# 6                                   None
# 7                                   None
# 8                                   None
#
#   param_randomforestregressor__n_estimators mean_test_score
# 0                                        50         0.46469
# 1                                       100        0.464717
# 2                                       150         0.46495
# 3                                        50         0.63119
# 4                                       100         0.63385
# 5                                       150        0.634941
# 6                                        50        0.631045
# 7                                       100        0.633741
# 8                                       150        0.634933

# %%
sns.regplot(
    x='param_randomforestregressor__max_depth',
    y='mean_test_score',
    data=results.T[['param_randomforestregressor__max_depth', 'mean_test_score']], 
    fit_reg=False
);

# %%
sns.regplot(
    x='param_randomforestregressor__n_estimators',
    y='mean_test_score',
    data=results.T[['param_randomforestregressor__n_estimators', 'mean_test_score']], 
    fit_reg=False
);
