# %%
import pandas as pd
from __future__ import division
import warnings
import seaborn as sns

warnings.filterwarnings("ignore", category=DeprecationWarning)
sns.set_style("whitegrid")
sns.set_context("poster")

from pylab import rcParams
rcParams['figure.figsize'] = 20, 5

# %matplotlib inline

# %%
df = pd.read_pickle('../data/data_w_transformed_census_and_removed_invalid_rows_and_cols_and_fixed_zips_and_descs_and_dropped_latlongs.pkl')
df.shape
# Out:
# (744372, 37)

# %%
df.COMPLETION_TIME.shape
# Out:
# (744372,)

# %%
y = df.COMPLETION_TIME.dropna()

# %%
y.describe()
# Out:
# count    678607.000000
# mean        555.653267
# std        1997.859653
# min           0.000278
# 25%           2.499722
# 50%          50.621667
# 75%         211.507361
# max       46001.385000
# Name: COMPLETION_TIME, dtype: float64

# %%
y.hist(figsize=(20,5));
