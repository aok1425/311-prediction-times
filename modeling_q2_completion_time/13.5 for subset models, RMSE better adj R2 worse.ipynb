# %%
import pandas as pd
import pickle

# %%
from __future__ import division
import pandas as pd
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import rcParams
# %matplotlib inline

warnings.filterwarnings("ignore", category=DeprecationWarning)
sns.set_style("whitegrid")
sns.set_context("poster")
# rcParams['figure.figsize'] = 20, 5

# %%
def need_more_alphas(result_table):
    """Make sure we don't need to look at more alphas,
    by checking that min and max alphas don't correspond to the highest score."""
    scores = result_table.loc['mean_test_score'].tolist()
    highest_score = max(scores)
    
    if scores[0] == highest_score:
        return True
    elif scores[-1] == highest_score:
        if scores[-1] == scores[-2]:
            return False
        else:
            return True
    else:
        return False

# %%
results = pickle.load(open('../data/lasso_q2_ea_model_results.pkl', 'rb'))
len(results)
# Out:
# 125

# %% [markdown]
# ### Looking at if I need more alphas

# %%
results.values()[19]['result'].loc['mean_test_score']
# Out:
# 0      -0.727651
# 1       -0.67573
# 2      -0.562566
# 3      -0.338584
# 4     -0.0574087
# 5      0.0984544
# 6       0.169834
# 7    -0.00484897
# 8    -0.00868369
# 9    -0.00868369
# 10   -0.00868369
# 11   -0.00868369
# 12   -0.00868369
# 13   -0.00868369
# 14   -0.00868369
# 15   -0.00868369
# 16   -0.00868369
# Name: mean_test_score, dtype: object

# %%
need_more_alphas(results.values()[20]['result'])
# Out:
# False

# %% [markdown]
# ### Looking at best scores

# %%
r = {}

for categ, result in results.iteritems():
    r[categ] = result['result'].loc['mean_test_score'].max()

# %%
df = pd.DataFrame(sorted(r.items(), key=lambda x: x[1])[::-1], columns=['categ', 'r2'])

# %%
df['needs_more_alphas'] = df.categ.map(lambda categ: need_more_alphas(results[categ]['result']))
df.shape
# Out:
# (125, 3)

# %%
results['Recycling Cart Return']['result']
# Out:
#                                                    0   \
# mean_fit_time                                0.120379
# mean_score_time                            0.00336995
# mean_test_score                               0.42787
# mean_train_score                             0.457179
# param_lassocv__alphas                        [0.0001]
# params                 {u'lassocv__alphas': [0.0001]}
# rank_test_score                                     5
# split0_test_score                            0.462282
# split0_train_score                           0.448196
# split1_test_score                            0.389531
# split1_train_score                           0.466378
# split2_test_score                            0.449923
# split2_train_score                           0.451504
# split3_test_score                            0.406041
# split3_train_score                           0.462727
# split4_test_score                            0.431515
# split4_train_score                           0.457093
# std_fit_time                                0.0190195
# std_score_time                            0.000177808
# std_test_score                              0.0269565
# std_train_score                            0.00675754
#
#                                                    1   \
# mean_fit_time                                0.068115
# mean_score_time                            0.00281811
# mean_test_score                              0.427949
# mean_train_score                             0.457163
# param_lassocv__alphas                        [0.0003]
# params                 {u'lassocv__alphas': [0.0003]}
# rank_test_score                                     4
# split0_test_score                            0.462695
# split0_train_score                           0.448178
# split1_test_score                            0.389472
# split1_train_score                           0.466362
# split2_test_score                            0.450084
# split2_train_score                           0.451485
# split3_test_score                            0.405872
# split3_train_score                           0.462712
# split4_test_score                            0.431563
# split4_train_score                           0.457076
# std_fit_time                               0.00438193
# std_score_time                            0.000300821
# std_test_score                               0.027134
# std_train_score                            0.00675845
#
#                                                   2   \
# mean_fit_time                              0.0621252
# mean_score_time                           0.00290761
# mean_test_score                             0.428099
# mean_train_score                            0.456976
# param_lassocv__alphas                        [0.001]
# params                 {u'lassocv__alphas': [0.001]}
# rank_test_score                                    3
# split0_test_score                           0.464015
# split0_train_score                          0.447982
# split1_test_score                           0.389117
# split1_train_score                          0.466179
# split2_test_score                           0.450487
# split2_train_score                           0.45128
# split3_test_score                            0.40526
# split3_train_score                          0.462549
# split4_test_score                           0.431557
# split4_train_score                          0.456892
# std_fit_time                              0.00422151
# std_score_time                           0.000999791
# std_test_score                             0.0277398
# std_train_score                           0.00676895
#
#                                                   3   \
# mean_fit_time                              0.0635358
# mean_score_time                           0.00239182
# mean_test_score                             0.428361
# mean_train_score                            0.455776
# param_lassocv__alphas                        [0.003]
# params                 {u'lassocv__alphas': [0.003]}
# rank_test_score                                    2
# split0_test_score                           0.466922
# split0_train_score                          0.446544
# split1_test_score                           0.389837
# split1_train_score                          0.465224
# split2_test_score                            0.45072
# split2_train_score                          0.450095
# split3_test_score                            0.40379
# split3_train_score                          0.461617
# split4_test_score                           0.430467
# split4_train_score                          0.455399
# std_fit_time                              0.00952411
# std_score_time                           7.65951e-05
# std_test_score                             0.0285739
# std_train_score                           0.00694315
#
#                                                  4   \
# mean_fit_time                             0.0590966
# mean_score_time                          0.00227041
# mean_test_score                            0.428808
# mean_train_score                           0.450962
# param_lassocv__alphas                        [0.01]
# params                 {u'lassocv__alphas': [0.01]}
# rank_test_score                                   1
# split0_test_score                          0.472864
# split0_train_score                         0.440761
# split1_test_score                          0.396451
# split1_train_score                         0.461026
# split2_test_score                          0.448444
# split2_train_score                         0.444906
# split3_test_score                          0.402415
# split3_train_score                         0.457287
# split4_test_score                          0.423767
# split4_train_score                         0.450831
# std_fit_time                             0.00967057
# std_score_time                          0.000194913
# std_test_score                            0.0286301
# std_train_score                          0.00751076
#
#                                                  5   \
# mean_fit_time                             0.0536456
# mean_score_time                          0.00231357
# mean_test_score                            0.427567
# mean_train_score                           0.441015
# param_lassocv__alphas                        [0.03]
# params                 {u'lassocv__alphas': [0.03]}
# rank_test_score                                   6
# split0_test_score                           0.46968
# split0_train_score                          0.42879
# split1_test_score                          0.404915
# split1_train_score                         0.449691
# split2_test_score                          0.440988
# split2_train_score                         0.435764
# split3_test_score                           0.40647
# split3_train_score                         0.448442
# split4_test_score                          0.415679
# split4_train_score                         0.442392
# std_fit_time                              0.0185281
# std_score_time                          8.73667e-05
# std_test_score                            0.0247188
# std_train_score                          0.00786586
#
#                                                 6   \
# mean_fit_time                            0.0507924
# mean_score_time                         0.00231018
# mean_test_score                           0.405856
# mean_train_score                           0.41259
# param_lassocv__alphas                        [0.1]
# params                 {u'lassocv__alphas': [0.1]}
# rank_test_score                                  7
# split0_test_score                         0.441226
# split0_train_score                        0.402807
# split1_test_score                         0.392544
# split1_train_score                        0.418674
# split2_test_score                         0.406555
# split2_train_score                        0.408245
# split3_test_score                         0.397689
# split3_train_score                        0.417818
# split4_test_score                         0.391193
# split4_train_score                        0.415407
# std_fit_time                            0.00951379
# std_score_time                         5.87231e-05
# std_test_score                           0.0185026
# std_train_score                         0.00611307
#
#                                                 7   \
# mean_fit_time                            0.0500554
# mean_score_time                         0.00411806
# mean_test_score                           0.326244
# mean_train_score                          0.329275
# param_lassocv__alphas                        [0.3]
# params                 {u'lassocv__alphas': [0.3]}
# rank_test_score                                  8
# split0_test_score                         0.335523
# split0_train_score                         0.31631
# split1_test_score                         0.327582
# split1_train_score                        0.334035
# split2_test_score                         0.322832
# split2_train_score                        0.329644
# split3_test_score                         0.336113
# split3_train_score                        0.333091
# split4_test_score                         0.309146
# split4_train_score                        0.333297
# std_fit_time                            0.00730397
# std_score_time                          0.00371777
# std_test_score                          0.00988567
# std_train_score                         0.00665762
#
#                                                 8   \
# mean_fit_time                            0.0450613
# mean_score_time                         0.00231299
# mean_test_score                        -0.00231629
# mean_train_score                                 0
# param_lassocv__alphas                        [1.0]
# params                 {u'lassocv__alphas': [1.0]}
# rank_test_score                                  9
# split0_test_score                       -6.277e-07
# split0_train_score                               0
# split1_test_score                      -0.00254985
# split1_train_score                               0
# split2_test_score                      -0.00276799
# split2_train_score                               0
# split3_test_score                      -0.00301335
# split3_train_score                               0
# split4_test_score                      -0.00325478
# split4_train_score                               0
# std_fit_time                            0.00275683
# std_score_time                         0.000119926
# std_test_score                          0.00118254
# std_train_score                                  0
#
#                                                 9   \
# mean_fit_time                            0.0493222
# mean_score_time                         0.00236402
# mean_test_score                        -0.00231629
# mean_train_score                                 0
# param_lassocv__alphas                        [3.0]
# params                 {u'lassocv__alphas': [3.0]}
# rank_test_score                                  9
# split0_test_score                       -6.277e-07
# split0_train_score                               0
# split1_test_score                      -0.00254985
# split1_train_score                               0
# split2_test_score                      -0.00276799
# split2_train_score                               0
# split3_test_score                      -0.00301335
# split3_train_score                               0
# split4_test_score                      -0.00325478
# split4_train_score                               0
# std_fit_time                            0.00734548
# std_score_time                         3.45615e-05
# std_test_score                          0.00118254
# std_train_score                                  0
#
#                                                  10  \
# mean_fit_time                              0.048696
# mean_score_time                           0.0023798
# mean_test_score                         -0.00231629
# mean_train_score                                  0
# param_lassocv__alphas                        [10.0]
# params                 {u'lassocv__alphas': [10.0]}
# rank_test_score                                   9
# split0_test_score                        -6.277e-07
# split0_train_score                                0
# split1_test_score                       -0.00254985
# split1_train_score                                0
# split2_test_score                       -0.00276799
# split2_train_score                                0
# split3_test_score                       -0.00301335
# split3_train_score                                0
# split4_test_score                       -0.00325478
# split4_train_score                                0
# std_fit_time                             0.00559389
# std_score_time                          0.000118469
# std_test_score                           0.00118254
# std_train_score                                   0
#
#                                                  11  \
# mean_fit_time                             0.0462204
# mean_score_time                          0.00234423
# mean_test_score                         -0.00231629
# mean_train_score                                  0
# param_lassocv__alphas                        [30.0]
# params                 {u'lassocv__alphas': [30.0]}
# rank_test_score                                   9
# split0_test_score                        -6.277e-07
# split0_train_score                                0
# split1_test_score                       -0.00254985
# split1_train_score                                0
# split2_test_score                       -0.00276799
# split2_train_score                                0
# split3_test_score                       -0.00301335
# split3_train_score                                0
# split4_test_score                       -0.00325478
# split4_train_score                                0
# std_fit_time                             0.00547198
# std_score_time                          4.30385e-05
# std_test_score                           0.00118254
# std_train_score                                   0
#
#                                                   12  \
# mean_fit_time                              0.0530042
# mean_score_time                            0.0025064
# mean_test_score                          -0.00231629
# mean_train_score                                   0
# param_lassocv__alphas                        [100.0]
# params                 {u'lassocv__alphas': [100.0]}
# rank_test_score                                    9
# split0_test_score                         -6.277e-07
# split0_train_score                                 0
# split1_test_score                        -0.00254985
# split1_train_score                                 0
# split2_test_score                        -0.00276799
# split2_train_score                                 0
# split3_test_score                        -0.00301335
# split3_train_score                                 0
# split4_test_score                        -0.00325478
# split4_train_score                                 0
# std_fit_time                               0.0141937
# std_score_time                           0.000370543
# std_test_score                            0.00118254
# std_train_score                                    0
#
#                                                   13  \
# mean_fit_time                              0.0525774
# mean_score_time                           0.00229573
# mean_test_score                          -0.00231629
# mean_train_score                                   0
# param_lassocv__alphas                        [300.0]
# params                 {u'lassocv__alphas': [300.0]}
# rank_test_score                                    9
# split0_test_score                         -6.277e-07
# split0_train_score                                 0
# split1_test_score                        -0.00254985
# split1_train_score                                 0
# split2_test_score                        -0.00276799
# split2_train_score                                 0
# split3_test_score                        -0.00301335
# split3_train_score                                 0
# split4_test_score                        -0.00325478
# split4_train_score                                 0
# std_fit_time                              0.00829725
# std_score_time                           9.60791e-05
# std_test_score                            0.00118254
# std_train_score                                    0
#
#                                                    14  \
# mean_fit_time                               0.0455906
# mean_score_time                            0.00239954
# mean_test_score                           -0.00231629
# mean_train_score                                    0
# param_lassocv__alphas                        [1000.0]
# params                 {u'lassocv__alphas': [1000.0]}
# rank_test_score                                     9
# split0_test_score                          -6.277e-07
# split0_train_score                                  0
# split1_test_score                         -0.00254985
# split1_train_score                                  0
# split2_test_score                         -0.00276799
# split2_train_score                                  0
# split3_test_score                         -0.00301335
# split3_train_score                                  0
# split4_test_score                         -0.00325478
# split4_train_score                                  0
# std_fit_time                               0.00497732
# std_score_time                            5.88392e-05
# std_test_score                             0.00118254
# std_train_score                                     0
#
#                                                    15  \
# mean_fit_time                                0.052766
# mean_score_time                            0.00244761
# mean_test_score                           -0.00231629
# mean_train_score                                    0
# param_lassocv__alphas                        [3000.0]
# params                 {u'lassocv__alphas': [3000.0]}
# rank_test_score                                     9
# split0_test_score                          -6.277e-07
# split0_train_score                                  0
# split1_test_score                         -0.00254985
# split1_train_score                                  0
# split2_test_score                         -0.00276799
# split2_train_score                                  0
# split3_test_score                         -0.00301335
# split3_train_score                                  0
# split4_test_score                         -0.00325478
# split4_train_score                                  0
# std_fit_time                               0.00709665
# std_score_time                            0.000162005
# std_test_score                             0.00118254
# std_train_score                                     0
#
#                                                     16
# mean_fit_time                                0.0412407
# mean_score_time                             0.00211763
# mean_test_score                            -0.00231629
# mean_train_score                                     0
# param_lassocv__alphas                        [10000.0]
# params                 {u'lassocv__alphas': [10000.0]}
# rank_test_score                                      9
# split0_test_score                           -6.277e-07
# split0_train_score                                   0
# split1_test_score                          -0.00254985
# split1_train_score                                   0
# split2_test_score                          -0.00276799
# split2_train_score                                   0
# split3_test_score                          -0.00301335
# split3_train_score                                   0
# split4_test_score                          -0.00325478
# split4_train_score                                   0
# std_fit_time                                0.00537299
# std_score_time                              0.00033641
# std_test_score                              0.00118254
# std_train_score                                      0

# %%
df1[df.needs_more_alphas]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-2bd564a9baf6> in <module>()
# ----> 1 df1[df.needs_more_alphas]
#
# NameError: name 'df1' is not defined

# %%
df_n = pd.DataFrame({'TYPE': {0: 'ADA',
  1: 'Abandoned Bicycle',
  2: 'Abandoned Building',
  3: 'Abandoned Vehicles',
  4: 'Alert Boston',
  5: 'Animal Found',
  6: 'Animal Generic Request',
  7: 'Animal Lost',
  8: 'Animal Noise Disturbances',
  9: 'Automotive Noise Disturbance',
  10: 'BWSC General Request',
  11: 'BWSC Pothole',
  12: 'Bed Bugs',
  13: 'Bicycle Issues',
  14: 'Big Buildings Online Request',
  15: 'Billing Complaint',
  16: 'Breathe Easy',
  17: 'Bridge Maintenance',
  18: 'Building Inspection Request',
  19: 'CE Collection',
  20: 'Call Log',
  21: 'Carbon Monoxide',
  22: 'Catchbasin',
  23: 'Cemetery Maintenance Request',
  24: 'Checkin',
  25: 'Chronic Dampness/Mold',
  26: 'City/State Snow Issues',
  27: 'Construction Debris',
  28: 'Contractor Complaints',
  29: 'Contractors Complaint',
  30: 'Corporate or Community Group Service Day Clean Up',
  31: 'Cross Metering - Sub-Metering',
  32: 'Downed Wire',
  33: 'Dumpster & Loading Noise Disturbances',
  34: 'Egress',
  35: 'Electrical',
  36: 'Empty Litter Basket',
  37: 'Equipment Repair',
  38: 'Exceeding Terms of Permit',
  39: 'Fire Department Request',
  40: 'Fire Hydrant',
  41: 'Fire in Food Establishment',
  42: 'Follow-Up',
  43: 'Food Alert - Confirmed',
  44: 'Food Alert - Unconfirmed',
  45: 'General Comments For An Employee',
  46: 'General Comments For a Program or Policy',
  47: 'General Lighting Request',
  48: 'General Traffic Engineering Request',
  49: 'Graffiti Removal',
  50: 'Ground Maintenance',
  51: 'HP Sign Application New',
  52: 'HP Sign Application Renewal',
  53: 'Heat - Excessive  Insufficient',
  54: 'Heat/Fuel Assistance',
  55: 'Highway Maintenance',
  56: 'Housing Discrimination Intake Form',
  57: 'Idea Collection',
  58: 'Illegal Auto Body Shop',
  59: 'Illegal Dumping',
  60: 'Illegal Occupancy',
  61: 'Illegal Posting of Signs',
  62: 'Illegal Rooming House',
  63: 'Illegal Use',
  64: 'Illegal Vending',
  65: 'Improper Storage of Trash (Barrels)',
  66: 'Install New Lighting',
  67: 'Item Price Missing',
  68: 'Knockdown Replacement',
  69: 'Lead',
  70: 'Litter Basket Maintenance',
  71: 'Loud Parties/Music/People',
  72: 'Maintenance - Homeowner',
  73: 'Maintenance Complaint - Residential',
  74: 'Major System Failure',
  75: 'Mechanical',
  76: 'Mice Infestation - Residential',
  77: 'Misc. Snow Complaint',
  78: 'Missed Trash/Recycling/Yard Waste/Bulk Item',
  79: 'Missing Sign',
  80: 'Mosquitoes (West Nile)',
  81: 'Municipal Parking Lot Complaints',
  82: 'Needle Pickup',
  83: 'New Sign  Crosswalk or Pavement Marking',
  84: 'New Tree Requests',
  85: 'New Tree Warrantee Inspection',
  86: 'News Boxes',
  87: 'No Price on Gas/Wrong Price',
  88: 'No Utilities - Food Establishment - Electricity',
  89: 'No Utilities - Food Establishment - Flood',
  90: 'No Utilities - Food Establishment - Sewer',
  91: 'No Utilities - Food Establishment - Water',
  92: 'No Utilities Residential - Electricity',
  93: 'No Utilities Residential - Gas',
  94: 'No Utilities Residential - Water',
  95: 'No-Tow Complaint Confirmation',
  96: 'Notification',
  97: 'OCR Front Desk Interactions',
  98: 'OCR Metrolist',
  99: 'Occupying W/Out A Valid CO/CI',
  100: 'One Boston Day',
  101: 'Overcrowding',
  102: 'Overflowing or Un-kept Dumpster',
  103: 'PWD Graffiti',
  104: 'Park Improvement Requests',
  105: 'Park Maintenance Requests',
  106: 'Parking Enforcement',
  107: 'Parking Meter Repairs',
  108: 'Parking on Front/Back Yards (Illegal Parking)',
  109: 'Parks General Request',
  110: 'Parks Lighting/Electrical Issues',
  111: 'Pavement Marking Inspection',
  112: 'Pavement Marking Maintenance',
  113: 'Pest Infestation - Residential',
  114: 'Phone Bank Service Inquiry',
  115: 'Pick up Dead Animal',
  116: 'Pigeon Infestation',
  117: 'Planting',
  118: 'Plumbing',
  119: 'Poor Conditions of Property',
  120: 'Poor Ventilation',
  121: 'Private Parking Lot Complaints',
  122: 'Product Short Measure',
  123: 'Protection of Adjoining Property',
  124: 'Public Events Noise Disturbances',
  125: 'Public Works General Request',
  126: 'Rat Bite',
  127: 'Recycling Cart Inquiry',
  128: 'Recycling Cart Return',
  129: 'Rental Unit Delivery Conditions',
  130: 'Request for Litter Basket Installation',
  131: 'Request for Pothole Repair',
  132: 'Request for Recycling Cart',
  133: 'Request for Snow Plowing',
  134: 'Request for Snow Plowing (Emergency Responder)',
  135: 'Requests for Street Cleaning',
  136: 'Requests for Traffic Signal Studies or Reviews',
  137: 'Roadway Flooding',
  138: 'Roadway Repair',
  139: 'Rodent Activity',
  140: 'Rooftop & Mechanical Disturbances',
  141: 'Scale Not Visible',
  142: 'Scanning Overcharge',
  143: 'Schedule a Bulk Item Pickup',
  144: 'Schedule a Bulk Item Pickup SS',
  145: 'Senior Shoveling',
  146: 'Sewage/Septic Back-Up',
  147: 'Short Measure - Gas',
  148: 'Sidewalk Cover / Manhole',
  149: 'Sidewalk Repair',
  150: 'Sidewalk Repair (Make Safe)',
  151: 'Sign Repair',
  152: 'Sign Shop WO',
  153: 'Snow Removal',
  154: 'Snow/Ice Control',
  155: 'Space Savers',
  156: 'Squalid Living Conditions',
  157: 'Sticker Request',
  158: 'Street Light Knock Downs',
  159: 'Street Light Outages',
  160: 'Student Move-in Issues',
  161: 'Student Overcrowding',
  162: 'Traffic Signal Inspection',
  163: 'Traffic Signal Repair',
  164: 'Transfer Not Completed',
  165: 'Transportation General Request',
  166: 'Trash on Vacant Lot',
  167: 'Tree Emergencies',
  168: 'Tree Maintenance Requests',
  169: 'Tree in Park',
  170: 'Undefined Noise Disturbance',
  171: 'Unit Pricing Wrong/Missing',
  172: 'Unsafe Dangerous Conditions',
  173: 'Unsanitary Conditions - Employees',
  174: 'Unsanitary Conditions - Establishment',
  175: 'Unsanitary Conditions - Food',
  176: 'Unsatisfactory Living Conditions',
  177: 'Unsatisfactory Utilities - Electrical  Plumbing',
  178: 'Unshoveled Sidewalk',
  179: 'Upgrade Existing Lighting',
  180: 'Utility Call-In',
  181: 'Utility Casting Repair',
  182: 'Valet Parking Problems',
  183: 'WC Call Log',
  184: 'Walk-In Service Inquiry',
  185: 'Water in Gas - High Priority',
  186: 'Watermain Break',
  187: 'Work Hours-Loud Noise Complaints',
  188: 'Work w/out Permit',
  189: 'Working Beyond Hours',
  190: 'Yardwaste Asian Longhorned Beetle Affected Area',
  191: 'Zoning'},
 'num_issues': {0: 1,
  1: 1115,
  2: 475,
  3: 8275,
  4: 15,
  5: 112,
  6: 1002,
  7: 85,
  8: 49,
  9: 3,
  10: 877,
  11: 86,
  12: 953,
  13: 76,
  14: 35,
  15: 52,
  16: 953,
  17: 52,
  18: 4559,
  19: 12,
  20: 2059,
  21: 84,
  22: 944,
  23: 69,
  24: 33,
  25: 770,
  26: 74,
  27: 168,
  28: 2655,
  29: 1039,
  30: 126,
  31: 648,
  32: 3,
  33: 14,
  34: 206,
  35: 1605,
  36: 4699,
  37: 2557,
  38: 323,
  39: 19,
  40: 790,
  41: 102,
  42: 4,
  43: 340,
  44: 454,
  45: 1800,
  46: 5421,
  47: 1827,
  48: 238,
  49: 16316,
  50: 3469,
  51: 2,
  52: 1,
  53: 2089,
  54: 2,
  55: 1972,
  56: 311,
  57: 6,
  58: 346,
  59: 1150,
  60: 968,
  61: 108,
  62: 545,
  63: 71,
  64: 57,
  65: 6940,
  66: 155,
  67: 41,
  68: 2,
  69: 109,
  70: 401,
  71: 19,
  72: 451,
  73: 666,
  74: 2137,
  75: 120,
  76: 1004,
  77: 1474,
  78: 40529,
  79: 1990,
  80: 64,
  81: 27,
  82: 1683,
  83: 3951,
  84: 2028,
  85: 1,
  86: 3,
  87: 47,
  88: 16,
  89: 19,
  90: 23,
  91: 22,
  92: 172,
  93: 66,
  94: 295,
  95: 591,
  96: 4599,
  97: 4335,
  98: 25,
  99: 54,
  100: 12,
  101: 110,
  102: 1418,
  103: 1594,
  104: 202,
  105: 395,
  106: 27284,
  107: 322,
  108: 243,
  109: 812,
  110: 991,
  111: 131,
  112: 420,
  113: 800,
  114: 51,
  115: 7400,
  116: 135,
  117: 48,
  118: 471,
  119: 3813,
  120: 25,
  121: 16,
  122: 16,
  123: 425,
  124: 2,
  125: 2089,
  126: 44,
  127: 867,
  128: 1986,
  129: 133,
  130: 525,
  131: 12854,
  132: 13187,
  133: 49135,
  134: 1303,
  135: 20238,
  136: 1186,
  137: 59,
  138: 737,
  139: 10243,
  140: 15,
  141: 5,
  142: 39,
  143: 62975,
  144: 20925,
  145: 2,
  146: 145,
  147: 127,
  148: 893,
  149: 1391,
  150: 11082,
  151: 7271,
  152: 18,
  153: 66,
  154: 20,
  155: 1633,
  156: 189,
  157: 10465,
  158: 1981,
  159: 21953,
  160: 358,
  161: 39,
  162: 2310,
  163: 9967,
  164: 1,
  165: 1106,
  166: 1060,
  167: 4531,
  168: 10931,
  169: 141,
  170: 8,
  171: 22,
  172: 2579,
  173: 192,
  174: 1546,
  175: 881,
  176: 11197,
  177: 266,
  178: 1906,
  179: 118,
  180: 2839,
  181: 1,
  182: 26,
  183: 8,
  184: 17,
  185: 14,
  186: 230,
  187: 825,
  188: 2395,
  189: 608,
  190: 6,
  191: 278}})

# %%
df1 = df.merge(df_n, left_on='categ', right_on='TYPE', how='left').drop('TYPE', axis=1)

# %%
df1.categ.head(10).tolist()
# Out:
# ['Recycling Cart Return',
#  'Recycling Cart Inquiry',
#  'Misc. Snow Complaint',
#  'Request for Snow Plowing',
#  'Notification',
#  'Illegal Auto Body Shop',
#  'Request for Snow Plowing (Emergency Responder)',
#  'Empty Litter Basket',
#  'Electrical',
#  'Needle Pickup']

# %%
from __future__ import division

def adj_r2(r2, n, p):
    aa = (n - 1) / (n - p - 1)
    bb = 1 - r2
    return 1 - bb * aa

# %%
adj_r2(0.54159918297330223, 101731, 252)
# Out:
# 0.5404608376581529

# %%
adj_r2(0.428383, 101731, 1986)
# Out:
# 0.41700154986766114

# %%
adj_r2(	0.410935, 101731, 867)
# Out:
# 0.40587150441688247

# %%
df1
# Out:
#                                                  categ        r2  \
# 0                                Recycling Cart Return  0.428383
# 1                               Recycling Cart Inquiry  0.410935
# 2                                 Misc. Snow Complaint  0.390456
# 3                             Request for Snow Plowing  0.370721
# 4                                         Notification  0.368601
# 5                               Illegal Auto Body Shop  0.350456
# 6       Request for Snow Plowing (Emergency Responder)  0.312560
# 7                                  Empty Litter Basket  0.296070
# 8                                           Electrical  0.290328
# 9                                        Needle Pickup  0.263681
# 10                                            Plumbing  0.257561
# 11                                 Highway Maintenance  0.222516
# 12                                        Space Savers  0.217030
# 13                                        PWD Graffiti  0.206591
# 14                           Exceeding Terms of Permit  0.201156
# 15                     Overflowing or Un-kept Dumpster  0.201023
# 16                           Tree Maintenance Requests  0.186513
# 17                                   Work w/out Permit  0.183227
# 18                                          Mechanical  0.169834
# 19                                        Animal Found  0.167872
# 20                                              Zoning  0.155288
# 21                           Traffic Signal Inspection  0.141726
# 22                          Request for Recycling Cart  0.138773
# 23                         Building Inspection Request  0.131925
# 24                                     Sidewalk Repair  0.130836
# 25                                    Equipment Repair  0.130539
# 26                                   Illegal Occupancy  0.125524
# 27                      Pest Infestation - Residential  0.123643
# 28                                   New Tree Requests  0.120721
# 29                                Working Beyond Hours  0.116618
# ..                                                 ...       ...
# 95                              Student Move-in Issues -0.003400
# 96                                     Illegal Dumping -0.006338
# 97                               Parking Meter Repairs -0.007000
# 98              No Utilities Residential - Electricity -0.008016
# 99                 Maintenance Complaint - Residential -0.009965
# 100                                         Catchbasin -0.010423
# 101    Unsatisfactory Utilities - Electrical  Plumbing -0.010461
# 102                               BWSC General Request -0.010829
# 103                          Squalid Living Conditions -0.013470
# 104                                 Abandoned Building -0.013713
# 105                                           Bed Bugs -0.014278
# 106                          Litter Basket Maintenance -0.014588
# 107                General Traffic Engineering Request -0.016981
# 108                   No Utilities Residential - Water -0.019867
# 109                                       Fire Hydrant -0.021998
# 110                          Park Maintenance Requests -0.027673
# 111                                             Egress -0.028182
# 112                                    Watermain Break -0.038794
# 113                                 Pigeon Infestation -0.043089
# 114                  Unsanitary Conditions - Employees -0.050357
# 115  Corporate or Community Group Service Day Clean Up -0.051775
# 116                        Pavement Marking Inspection -0.062150
# 117                                       Overcrowding -0.065106
# 118                               Install New Lighting -0.076451
# 119                                               Lead -0.077317
# 120                                Construction Debris -0.118056
# 121                           Illegal Posting of Signs -0.121362
# 122                              Sewage/Septic Back-Up -0.152229
# 123                                       Tree in Park -0.190915
# 124                                Short Measure - Gas -0.414971
#
#     needs_more_alphas  num_issues
# 0               False        1986
# 1               False         867
# 2               False        1474
# 3               False       49135
# 4               False        4599
# 5               False         346
# 6               False        1303
# 7               False        4699
# 8               False        1605
# 9               False        1683
# 10              False         471
# 11              False        1972
# 12              False        1633
# 13              False        1594
# 14              False         323
# 15              False        1418
# 16              False       10931
# 17              False        2395
# 18              False         120
# 19              False         112
# 20              False         278
# 21              False        2310
# 22              False       13187
# 23              False        4559
# 24              False        1391
# 25              False        2557
# 26              False         968
# 27              False         800
# 28              False        2028
# 29              False         608
# ..                ...         ...
# 95              False         358
# 96              False        1150
# 97              False         322
# 98              False         172
# 99              False         666
# 100             False         944
# 101             False         266
# 102             False         877
# 103             False         189
# 104             False         475
# 105             False         953
# 106             False         401
# 107             False         238
# 108             False         295
# 109             False         790
# 110             False         395
# 111             False         206
# 112             False         230
# 113             False         135
# 114             False         192
# 115             False         126
# 116             False         131
# 117             False         110
# 118             False         155
# 119             False         109
# 120             False         168
# 121             False         108
# 122             False         145
# 123             False         141
# 124             False         127
#
# [125 rows x 4 columns]

# %%
ax = sns.regplot(x='r2', y='num_issues', data=df1, fit_reg=False)
ax.set_yscale('log')
ax.set_title('Little correlation btwn the # of issues and performance of model');

# %% [markdown]
# ## Can we get RMSE for Recycling Cart Return?

# %%
results['Recycling Cart Return']['rmse']
# Out:
# 1.0736440111561754

# %%
df1['rmse'] = df1.categ.map(lambda x: results[x]['rmse'])
df1.head()
# Out:
#                       categ        r2 needs_more_alphas  num_issues      rmse
# 0     Recycling Cart Return  0.428808             False        1986  1.073644
# 1    Recycling Cart Inquiry  0.409995             False         867  0.361936
# 2      Misc. Snow Complaint  0.393860             False        1474  0.672877
# 3  Request for Snow Plowing  0.370317              True       49135  0.564306
# 4              Notification  0.368611             False        4599  0.327298

# %%
df1[df1.rmse < 0.75].sort_values('r2', ascending=False)
# Out:
#                                                  categ        r2  \
# 1                               Recycling Cart Inquiry  0.409995
# 2                                 Misc. Snow Complaint  0.393860
# 3                             Request for Snow Plowing  0.370317
# 4                                         Notification  0.368611
# 5                               Illegal Auto Body Shop  0.350456
# 8                                           Electrical  0.290656
# 10                                            Plumbing  0.259117
# 15                     Overflowing or Un-kept Dumpster  0.200968
# 16                                   Work w/out Permit  0.185823
# 20                                              Zoning  0.154914
# 21                           Traffic Signal Inspection  0.143678
# 22                          Request for Recycling Cart  0.139504
# 23                                     Sidewalk Repair  0.136075
# 24                         Building Inspection Request  0.132935
# 25                                   Illegal Occupancy  0.132502
# 26                                    Equipment Repair  0.128114
# 27                      Pest Infestation - Residential  0.123877
# 28                                   New Tree Requests  0.121062
# 29                                    Graffiti Removal  0.114552
# 30                                Working Beyond Hours  0.114305
# 31                               Contractors Complaint  0.113356
# 34                         Unsafe Dangerous Conditions  0.102245
# 35                    Protection of Adjoining Property  0.100840
# 37                         Schedule a Bulk Item Pickup  0.098656
# 39                              Animal Generic Request  0.084650
# 40                      Schedule a Bulk Item Pickup SS  0.077196
# 42              Request for Litter Basket Installation  0.073040
# 43                             Maintenance - Homeowner  0.071631
# 45                           Upgrade Existing Lighting  0.063288
# 47                                     Rodent Activity  0.061448
# ..                                                 ...       ...
# 64                                     Utility Call-In  0.036367
# 69                                 Trash on Vacant Lot  0.022077
# 70                               Illegal Rooming House  0.020998
# 73                                            Call Log  0.020433
# 74                                 Pick up Dead Animal  0.019293
# 76                            Food Alert - Unconfirmed  0.016533
# 77                                         Sign Repair  0.016199
# 78                              Food Alert - Confirmed  0.015117
# 79                               Contractor Complaints  0.011029
# 81               Unsanitary Conditions - Establishment  0.010189
# 84                               Chronic Dampness/Mold  0.003385
# 85                        Unsanitary Conditions - Food  0.002586
# 90                                        Missing Sign -0.000983
# 94                      Mice Infestation - Residential -0.002643
# 96                              Student Move-in Issues -0.004401
# 97                               Parking Meter Repairs -0.007000
# 99                 Maintenance Complaint - Residential -0.008779
# 102    Unsatisfactory Utilities - Electrical  Plumbing -0.010440
# 104                          Squalid Living Conditions -0.013470
# 105                                 Abandoned Building -0.013713
# 109                                       Fire Hydrant -0.023089
# 111                                             Egress -0.028182
# 113                                 Pigeon Infestation -0.043089
# 114                  Unsanitary Conditions - Employees -0.049050
# 115  Corporate or Community Group Service Day Clean Up -0.051775
# 117                                       Overcrowding -0.065106
# 118                               Install New Lighting -0.076451
# 119                                               Lead -0.077317
# 120                                Construction Debris -0.118056
# 124                                Short Measure - Gas -0.414971
#
#     needs_more_alphas  num_issues      rmse
# 1               False         867  0.361936
# 2               False        1474  0.672877
# 3                True       49135  0.564306
# 4               False        4599  0.327298
# 5               False         346  0.747601
# 8               False        1605  0.622380
# 10              False         471  0.668490
# 15              False        1418  0.615233
# 16              False        2395  0.629426
# 20              False         278  0.728633
# 21              False        2310  0.680026
# 22              False       13187  0.401089
# 23              False        1391  0.667791
# 24              False        4559  0.640097
# 25              False         968  0.643026
# 26              False        2557  0.693173
# 27              False         800  0.522685
# 28              False        2028  0.536690
# 29              False       16316  0.547358
# 30              False         608  0.552874
# 31              False        1039  0.675237
# 34              False        2579  0.677234
# 35              False         425  0.652269
# 37               True       62975  0.328038
# 39              False        1002  0.713575
# 40              False       20925  0.294869
# 42              False         525  0.679818
# 43              False         451  0.663846
# 45              False         118  0.509403
# 47              False       10243  0.507666
# ..                ...         ...       ...
# 64              False        2839  0.688723
# 69              False        1060  0.551582
# 70              False         545  0.601466
# 73               True        2059  0.369579
# 74              False        7400  0.583254
# 76              False         454  0.387956
# 77              False        7271  0.548774
# 78              False         340  0.318033
# 79              False        2655  0.563860
# 81              False        1546  0.338252
# 84              False         770  0.553855
# 85              False         881  0.333430
# 90              False        1990  0.496135
# 94              False        1004  0.437954
# 96              False         358  0.659340
# 97              False         322  0.602725
# 99              False         666  0.693097
# 102             False         266  0.637074
# 104             False         189  0.588206
# 105             False         475  0.674426
# 109             False         790  0.636939
# 111             False         206  0.680435
# 113             False         135  0.582709
# 114             False         192  0.290990
# 115             False         126  0.704937
# 117             False         110  0.624540
# 118             False         155  0.640838
# 119             False         109  0.698740
# 120             False         168  0.714497
# 124             False         127  0.640618
#
# [71 rows x 5 columns]
